# %%
# !pip install python-dotenv

# %%
# !pip install openai

# %%
import pandas as pd
import openai

# %%
client = openai.OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key= x,
)

# %%
import json
import re
import requests

# %%
df = pd.read_csv('prompt_data.csv')
df
# Out:
#            Location Start Date End Date  Budget  \
# 0           Orlando     20-jul   22-jul  300,00
# 1   Washington D.C.     31-ago   2-sept  300,00
# 2            Boston     27-oct   29-oct  300,00
# 3       New Orleans     20-ago   22-ago  300,00
# 4           Seattle      3-jul    5-jul  300,00
# 5          Honolulu     9-sept  11-sept  300,00
# 6         San Diego     21-nov   23-nov  300,00
# 7         Nashville     26-jul   28-jul  300,00
# 8            Austin     20-jun   22-jun  300,00
# 9      Philadelphia     30-oct    1-nov  300,00
# 10          Atlanta      2-dic    4-dic  300,00
# 11         Portland      7-nov    9-nov  300,00
# 12      San Antonio     17-ago   19-ago  300,00
# 13           Denver     5-sept   7-sept  300,00
# 14           Dallas      1-nov    3-nov  300,00
# 15      Minneapolis     16-dic   18-dic  300,00
# 16   Salt Lake City     20-ago   24-ago  400,00
# 17        Cape Town      7-dic   11-dic  400,00
# 18           Sydney     17-ago   21-ago  400,00
# 19   Rio de Janeiro      5-oct    9-oct  400,00
# 20      Los Angeles     26-jul   30-jul  400,00
# 21         Florence     23-nov   27-nov  400,00
# 22            Seoul     21-dic   25-dic  400,00
# 23           Vienna      4-nov    8-nov  400,00
# 24          Toronto     24-ago   28-ago  400,00
# 25        Melbourne     21-jun   25-jun  400,00
# 26     Buenos Aires     20-jul   24-jul  400,00
# 27      Mexico City      3-oct    7-oct  400,00
# 28           Prague      9-dic   13-dic  400,00
# 29         Shanghai      7-ago   11-ago  400,00
# 30        Hong Kong     19-jul   23-jul  400,00
# 31          Chicago     30-nov    4-dic  400,00
# 32        Las Vegas     21-ago   25-ago  400,00
# 33            Miami     25-nov    1-dic  500,00
# 34            Tokyo      7-oct   13-oct  500,00
# 35            Paris      9-ago   15-ago  500,00
# 36    New York City     28-jun    4-jul  500,00
# 37           London    20-sept  26-sept  500,00
# 38             Rome      6-dic   12-dic  500,00
# 39          Bangkok     21-oct   27-oct  500,00
# 40            Dubai     28-jul    3-ago  500,00
# 41        Singapore     22-nov   28-nov  500,00
# 42        Barcelona      3-ago    9-ago  500,00
# 43         Istanbul     30-jun    6-jul  500,00
# 44        Amsterdam    21-sept  27-sept  500,00
# 45           Berlin      9-dic   15-dic  500,00
# 46           Madrid     21-oct   27-oct  500,00
# 47           Lisbon     27-jul    2-ago  500,00
# 48           Venice     21-ago   27-ago  500,00
# 49    San Francisco      2-jul    8-jul  500,00
#
#                              Interests
# 0                   Cafes, Art, Hiking
# 1       Live Sports, Desserts, Beaches
# 2          Sightseeing, Bars, Shopping
# 3          Museums, Restaurants, Parks
# 4                   Art, Hiking, Cafes
# 5           Bars, Beaches, Live Sports
# 6          Bars, Shopping, Sightseeing
# 7          Restaurants, Parks, Museums
# 8                   Hiking, Cafes, Art
# 9       Live Sports, Desserts, Beaches
# 10         Sightseeing, Bars, Shopping
# 11         Museums, Restaurants, Parks
# 12                  Cafes, Art, Hiking
# 13      Live Sports, Desserts, Beaches
# 14         Sightseeing, Bars, Shopping
# 15         Museums, Restaurants, Parks
# 16               Parks, Cafes, Beaches
# 17        Cafes, Live Sports, Shopping
# 18           Live Sports, Cafes, Parks
# 19     Sightseeing, Live Sports, Cafes
# 20        Museums, Sightseeing, Hiking
# 21               Art, Museums, Beaches
# 22                Cafes, Art, Shopping
# 23        Live Sports, Desserts, Parks
# 24            Sightseeing, Bars, Cafes
# 25   Museums, Restaurants, Live Sports
# 26            Art, Hiking, Sightseeing
# 27          Desserts, Beaches, Museums
# 28                 Bars, Shopping, Art
# 29        Restaurants, Parks, Desserts
# 30                 Hiking, Cafes, Bars
# 31   Beaches, Live Sports, Restaurants
# 32       Shopping, Sightseeing, Hiking
# 33      Museums, Shopping, Live Sports
# 34             Art, Parks, Sightseeing
# 35         Cafes, Restaurants, Museums
# 36            Live Sports, Hiking, Art
# 37      Sightseeing, Beaches, Desserts
# 38             Museums, Shopping, Bars
# 39             Art, Parks, Restaurants
# 40             Desserts, Cafes, Hiking
# 41              Bars, Sports, Shopping
# 42  Restaurants, Sightseeing, Shopping
# 43               Hiking, Museums, Bars
# 44           Beaches, Art, Restaurants
# 45          Shopping, Desserts, Hiking
# 46                Parks, Bars, Beaches
# 47        Cafes, Restaurants, Shopping
# 48          Live Sports, Hiking, Parks
# 49         Sightseeing, Beaches, Cafes

# %%
# Function to calculate total travel time
def calculate_total_travel_time(travel_plan, api_key):
    total_travel_time = 0  # in seconds

    # Base URL for Google Maps Distance Matrix API
    base_url = "https://maps.googleapis.com/maps/api/distancematrix/json"

    # Iterate through the travel plan to get the addresses
    for i in range(len(travel_plan) - 1):
        origin = travel_plan[i]["address"]
        destination = travel_plan[i + 1]["address"]

        # Parameters for the API request
        params = {
            "origins": origin,
            "destinations": destination,
            "key": api_key
        }

        # Make the API request
        response = requests.get(base_url, params=params)
        data = response.json()

        if response.status_code == 200:
            # Extract the travel time from the response
            travel_time = data["rows"][0]["elements"][0]["duration"]["value"]
            total_travel_time += travel_time
        else:
            print(f"Error fetching data from Google Maps API: {data['error_message']}")
            return None

    # Convert total travel time from seconds to hours and minutes
    total_travel_time_hours = total_travel_time // 3600
    total_travel_time_minutes = total_travel_time // 60

    return total_travel_time_minutes

def clean_json(content):
    # Remove leading/trailing whitespace and backticks
    content = content.strip('`').strip()
    # Remove any numbering or extraneous characters
    content = re.sub(r'^\d+\.\s*', '', content, flags=re.MULTILINE)
    # Remove trailing commas before closing braces or brackets
    content = re.sub(r',\s*(\]|\})', r'\1', content)
    # Remove non-JSON content
    content = re.sub(r'```json|```', '', content)
    return content

def calculate_budget_utilization(budget, travel_plan):
    # Calculate the total cost of activities in the travel plan
    total_cost = sum(activity["price"] for activity in travel_plan)
    
    # If the total cost exceeds the budget, return 0
    if total_cost > budget:
        return 0
    
    # Calculate the percentage of budget utilization
    budget_utilization_percentage = (total_cost / budget) * 100
    
    return budget_utilization_percentage

def calculate_satisfaction_percentage(interests, travel_plan):
    # Convert interests to a set of lowercase strings
    interests_set = set(interest.lower() for interest in interests)
    
    # Get a list of all activity categories in the travel plan
    activity_categories = {activity["category"].lower() for activity in travel_plan}
    
    # Calculate the number of satisfied interests
    satisfied_interests_count = sum(1 for interest in interests_set if interest in activity_categories)
    
    # Calculate the percentage of interests satisfied
    satisfaction_percentage = (satisfied_interests_count / len(interests_set)) * 100
    
    return satisfaction_percentage

def calculate_activity_score(travel_plan):
    repetition_penalty = 5      # Penalty for each repeated category

    # Count the occurrences of each activity category
    category_count = {}
    for activity in travel_plan:
        category = activity["category"].lower()
        if category in category_count:
            category_count[category] += 1
        else:
            category_count[category] = 1

    # Calculate the score
    unique_categories = len(category_count)
    repetitions = sum(count - 1 for count in category_count.values() if count > len(travel_plan)/len(category_count))

    # Initial score based on unique categories
    score = 100 - (repetitions * repetition_penalty)

    # Ensure the score is within the 0-100 range
    score = max(0, min(100, score))

    return score

# %%
import pandas as pd

# Step 1: Read the Excel file
df = pd.read_csv('prompt_data.csv')

responses = []
columns = ['interests_score', 'budget_score', 'travel_time_score']
df_eval_metrics = pd.DataFrame(columns=columns)

# Step 2: Generate sentences if the column names are correct
sentences = []

# %%
for index, row in df.iloc[40:].iterrows():
    location = row['Location']
    start_date = row['Start Date']
    end_date = row['End Date']
    budget = row['Budget']
    interests = row['Interests'].split(', ')  # Split the interests by comma and space

    sentence = f"Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: {location} Start date: {start_date} End Date: {end_date} Budget: {budget} Interests: {', '.join(interests[:3])}"
    system_message = "You are a travel provider and will respond with a list of activities. Please ensure output is only JSON response and each activity is described in a clean JSON format ready for parsing, with keys for address, date, time start, time end, price, and activity category. Example format: {'address': '5419 W Adams Blvd, Los Angeles, CA 90016', 'date': '2024-09-01', 'time_start': '09:00', 'time_end': '11:00', 'price': 10, 'category': 'Coffee'}."
    sentences.append(sentence)
    # Make API call with each sentence
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": sentence}
        ],
        temperature=0.5
    )
    
    # Print the response
    response_content = (response.choices[0].message.content)
    #print(f"Raw response content:\n{response_content}\n")  # Debugging print

    # Clean the JSON content
    cleaned_content = clean_json(response_content)
    print(f"Cleaned response content:\n{cleaned_content}\n")  # Debugging print

    try:
        response_json = json.loads(cleaned_content)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        response_json = {}

    # Add the response JSON to the list
    responses.append(response_json)
    
    # Calculate and print the percentage of budget utilization
    budget_utilization_percentage = calculate_budget_utilization(int(budget[:-3]), response_json)
    print(budget_utilization_percentage)
    
    satisfaction_percentage = calculate_satisfaction_percentage(interests, response_json)
    print(satisfaction_percentage)
    
    total_travel_time_minutes = calculate_total_travel_time(response_json, api_key)
    print(f"Total Travel Time: {total_travel_time_minutes} minutes")
    
    
    activity_score = calculate_activity_score(response_json)
    print(f"Activity Score: {activity_score}")

    new_row = {
        'location' : location,
        'interests_score': satisfaction_percentage,
        'budget_score': budget_utilization_percentage,
        'travel_time_score': total_travel_time_minutes,
        'redundency_score': activity_score
    }
    df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Out:
# Cleaned response content:
# [
#   {
#     "address": "Sheikh Mohammed bin Rashid Blvd, Dubai, UAE",
#     "date": "2023-07-28",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 15,
#     "category": "Café"
#   },
#   {
#     "address": "Dubai Hills, Dubai, UAE",
#     "date": "2023-07-28",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Jumeirah Beach Rd, Dubai, UAE",
#     "date": "2023-07-28",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 20,
#     "category": "Desserts"
#   },
#   {
#     "address": "Al Wasl Rd, Dubai, UAE",
#     "date": "2023-07-29",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 10,
#     "category": "Café"
#   },
#   {
#     "address": "Hatta, Dubai, UAE",
#     "date": "2023-07-29",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Downtown Dubai, Dubai, UAE",
#     "date": "2023-07-29",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 25,
#     "category": "Desserts"
#   },
#   {
#     "address": "Al Safa St, Dubai, UAE",
#     "date": "2023-07-30",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 12,
#     "category": "Café"
#   },
#   {
#     "address": "Mushrif Park, Dubai, UAE",
#     "date": "2023-07-30",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "The Palm Jumeirah, Dubai, UAE",
#     "date": "2023-07-30",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 30,
#     "category": "Desserts"
#   },
#   {
#     "address": "City Walk, Dubai, UAE",
#     "date": "2023-07-31",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 15,
#     "category": "Café"
#   },
#   {
#     "address": "Jebel Ali, Dubai, UAE",
#     "date": "2023-07-31",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Bluewaters Island, Dubai, UAE",
#     "date": "2023-07-31",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 20,
#     "category": "Desserts"
#   },
#   {
#     "address": "Dubai Marina, Dubai, UAE",
#     "date": "2023-08-01",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 10,
#     "category": "Café"
#   },
#   {
#     "address": "Al Qudra, Dubai, UAE",
#     "date": "2023-08-01",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "La Mer, Dubai, UAE",
#     "date": "2023-08-01",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 25,
#     "category": "Desserts"
#   },
#   {
#     "address": "JBR, Dubai, UAE",
#     "date": "2023-08-02",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 12,
#     "category": "Café"
#   },
#   {
#     "address": "Al Barsha, Dubai, UAE",
#     "date": "2023-08-02",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Dubai Creek, Dubai, UAE",
#     "date": "2023-08-02",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 20,
#     "category": "Desserts"
#   },
#   {
#     "address": "Burj Khalifa, Dubai, UAE",
#     "date": "2023-08-03",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 15,
#     "category": "Café"
#   },
#   {
#     "address": "Al Marmoom Desert Conservation Reserve, Dubai, UAE",
#     "date": "2023-08-03",
#     "time_start": "12:00",
#     "time_end": "15:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Dubai Mall, Dubai, UAE",
#     "date": "2023-08-03",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 30,
#     "category": "Desserts"
#   }
# ]
#
# 51.800000000000004
# 66.66666666666666
# Total Travel Time: 676 minutes
# Activity Score: 100
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#     {
#         "address": "1 Fullerton Rd, Singapore 049213",
#         "date": "2023-11-22",
#         "time_start": "18:00",
#         "time_end": "22:00",
#         "price": 50,
#         "category": "Bars"
#     },
#     {
#         "address": "8 Sentosa Gateway, Singapore 098269",
#         "date": "2023-11-23",
#         "time_start": "10:00",
#         "time_end": "14:00",
#         "price": 80,
#         "category": "Sports"
#     },
#     {
#         "address": "2 Orchard Turn, ION Orchard, Singapore 238801",
#         "date": "2023-11-23",
#         "time_start": "15:00",
#         "time_end": "19:00",
#         "price": 100,
#         "category": "Shopping"
#     },
#     {
#         "address": "30 Victoria St, CHIJMES, Singapore 187996",
#         "date": "2023-11-24",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 60,
#         "category": "Bars"
#     },
#     {
#         "address": "1 Stadium Dr, Singapore 397629",
#         "date": "2023-11-25",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 70,
#         "category": "Sports"
#     },
#     {
#         "address": "391 Orchard Rd, Ngee Ann City, Singapore 238872",
#         "date": "2023-11-25",
#         "time_start": "13:00",
#         "time_end": "17:00",
#         "price": 120,
#         "category": "Shopping"
#     },
#     {
#         "address": "328 North Bridge Rd, Singapore 188719",
#         "date": "2023-11-26",
#         "time_start": "18:00",
#         "time_end": "21:00",
#         "price": 50,
#         "category": "Bars"
#     },
#     {
#         "address": "6 Raffles Blvd, Singapore 039594",
#         "date": "2023-11-27",
#         "time_start": "10:00",
#         "time_end": "13:00",
#         "price": 70,
#         "category": "Sports"
#     },
#     {
#         "address": "2 Bayfront Ave, Marina Bay Sands, Singapore 018972",
#         "date": "2023-11-27",
#         "time_start": "14:00",
#         "time_end": "18:00",
#         "price": 100,
#         "category": "Shopping"
#     },
#     {
#         "address": "3E River Valley Rd, Singapore 179024",
#         "date": "2023-11-28",
#         "time_start": "19:00",
#         "time_end": "23:00",
#         "price": 50,
#         "category": "Bars"
#     }
# ]
#
# 0
# 100.0
# Total Travel Time: 79 minutes
# Activity Score: 85
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#   {
#     "address": "Carrer de Mallorca, 401, 08013 Barcelona, Spain",
#     "date": "2024-08-03",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 26,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Passeig de Gràcia, 43, 08007 Barcelona, Spain",
#     "date": "2024-08-03",
#     "time_start": "12:00",
#     "time_end": "14:00",
#     "price": 50,
#     "category": "Shopping"
#   },
#   {
#     "address": "Rambla de Catalunya, 37, 08007 Barcelona, Spain",
#     "date": "2024-08-03",
#     "time_start": "15:00",
#     "time_end": "17:00",
#     "price": 60,
#     "category": "Restaurants"
#   },
#   {
#     "address": "Carrer de Montcada, 15-23, 08003 Barcelona, Spain",
#     "date": "2024-08-04",
#     "time_start": "10:00",
#     "time_end": "12:00",
#     "price": 12,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Passeig de Gràcia, 49, 08007 Barcelona, Spain",
#     "date": "2024-08-04",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 45,
#     "category": "Shopping"
#   },
#   {
#     "address": "Carrer de Provença, 286-288, 08008 Barcelona, Spain",
#     "date": "2024-08-04",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 55,
#     "category": "Restaurants"
#   },
#   {
#     "address": "Plaça de Catalunya, 08002 Barcelona, Spain",
#     "date": "2024-08-05",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 0,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Carrer de Pelai, 08001 Barcelona, Spain",
#     "date": "2024-08-05",
#     "time_start": "12:00",
#     "time_end": "14:00",
#     "price": 40,
#     "category": "Shopping"
#   },
#   {
#     "address": "Carrer de la Princesa, 14, 08003 Barcelona, Spain",
#     "date": "2024-08-05",
#     "time_start": "15:00",
#     "time_end": "17:00",
#     "price": 50,
#     "category": "Restaurants"
#   },
#   {
#     "address": "Carrer de Sant Pere Més Alt, 1, 08003 Barcelona, Spain",
#     "date": "2024-08-06",
#     "time_start": "10:00",
#     "time_end": "12:00",
#     "price": 15,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Avinguda Diagonal, 08013 Barcelona, Spain",
#     "date": "2024-08-06",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 35,
#     "category": "Shopping"
#   },
#   {
#     "address": "Carrer de Pau Claris, 150, 08009 Barcelona, Spain",
#     "date": "2024-08-06",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 55,
#     "category": "Restaurants"
#   },
#   {
#     "address": "Carrer de la Marina, 08005 Barcelona, Spain",
#     "date": "2024-08-07",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 0,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Avinguda del Portal de l'Àngel, 08002 Barcelona, Spain",
#     "date": "2024-08-07",
#     "time_start": "12:00",
#     "time_end": "14:00",
#     "price": 45,
#     "category": "Shopping"
#   },
#   {
#     "address": "Carrer de Balmes, 65, 08007 Barcelona, Spain",
#     "date": "2024-08-07",
#     "time_start": "15:00",
#     "time_end": "17:00",
#     "price": 50,
#     "category": "Restaurants"
#   },
#   {
#     "address": "Carrer de Montjuïc del Bisbe, 3, 08002 Barcelona, Spain",
#     "date": "2024-08-08",
#     "time_start": "10:00",
#     "time_end": "12:00",
#     "price": 10,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Carrer de la Portaferrissa, 08002 Barcelona, Spain",
#     "date": "2024-08-08",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 40,
#     "category": "Shopping"
#   },
#   {
#     "address": "Carrer de Mallorca, 236, 08008 Barcelona, Spain",
#     "date": "2024-08-08",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 55,
#     "category": "Restaurants"
#   },
#   {
#     "address": "Carrer de la Marina, 08013 Barcelona, Spain",
#     "date": "2024-08-09",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 0,
#     "category": "Sightseeing"
#   },
#   {
#     "address": "Carrer de Pelai, 08001 Barcelona, Spain",
#     "date": "2024-08-09",
#     "time_start": "12:00",
#     "time_end": "14:00",
#     "price": 35,
#     "category": "Shopping"
#   },
#   {
#     "address": "Carrer de la Princesa, 14, 08003 Barcelona, Spain",
#     "date": "2024-08-09",
#     "time_start": "15:00",
#     "time_end": "17:00",
#     "price": 50,
#     "category": "Restaurants"
#   }
# ]
#
# 0
# 100.0
# Total Travel Time: 189 minutes
# Activity Score: 100
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#   {
#     "address": "Alemdar, Yerebatan Cd. 1/3, 34110 Fatih/Istanbul, Turkey",
#     "date": "2024-06-30",
#     "time_start": "09:00",
#     "time_end": "11:00",
#     "price": 15,
#     "category": "Museum"
#   },
#   {
#     "address": "Cankurtaran, Ayasofya Meydanı, 34122 Fatih/Istanbul, Turkey",
#     "date": "2024-06-30",
#     "time_start": "12:00",
#     "time_end": "14:00",
#     "price": 20,
#     "category": "Museum"
#   },
#   {
#     "address": "Şahkulu, Galip Dede Cd. No:56, 34421 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-06-30",
#     "time_start": "15:00",
#     "time_end": "17:00",
#     "price": 10,
#     "category": "Bar"
#   },
#   {
#     "address": "Cihangir, Akarsu Ykş. No:46, 34433 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-01",
#     "time_start": "09:00",
#     "time_end": "12:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Hoca Paşa, Ebussuud Cd. No:12, 34110 Fatih/Istanbul, Turkey",
#     "date": "2024-07-01",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 25,
#     "category": "Museum"
#   },
#   {
#     "address": "Asmalı Mescit, İstiklal Cd. No:64, 34430 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-01",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 12,
#     "category": "Bar"
#   },
#   {
#     "address": "Emirgan, 34467 Sarıyer/Istanbul, Turkey",
#     "date": "2024-07-02",
#     "time_start": "09:00",
#     "time_end": "12:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Cankurtaran, Topkapı Sarayı, 34122 Fatih/Istanbul, Turkey",
#     "date": "2024-07-02",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 30,
#     "category": "Museum"
#   },
#   {
#     "address": "Karaköy, Kemankeş Karamustafa Paşa, 34425 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-02",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 15,
#     "category": "Bar"
#   },
#   {
#     "address": "Polonezköy, 34829 Beykoz/Istanbul, Turkey",
#     "date": "2024-07-03",
#     "time_start": "09:00",
#     "time_end": "12:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Sultan Ahmet, 34122 Fatih/Istanbul, Turkey",
#     "date": "2024-07-03",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 20,
#     "category": "Museum"
#   },
#   {
#     "address": "Kadıköy, Caferağa, 34710 Kadıköy/Istanbul, Turkey",
#     "date": "2024-07-03",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 10,
#     "category": "Bar"
#   },
#   {
#     "address": "Belgrad Ormanı, 34450 Sarıyer/Istanbul, Turkey",
#     "date": "2024-07-04",
#     "time_start": "09:00",
#     "time_end": "12:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Gümüşsuyu, İnönü Cd. No:8, 34437 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-04",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 18,
#     "category": "Museum"
#   },
#   {
#     "address": "Beyoğlu, Asmalı Mescit, 34430 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-04",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 12,
#     "category": "Bar"
#   },
#   {
#     "address": "Aydos Ormanı, 34956 Kartal/Istanbul, Turkey",
#     "date": "2024-07-05",
#     "time_start": "09:00",
#     "time_end": "12:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Beyoğlu, İstiklal Cd. No: 245, 34430 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-05",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 20,
#     "category": "Museum"
#   },
#   {
#     "address": "Kadıköy, Moda Cd. No: 123, 34710 Kadıköy/Istanbul, Turkey",
#     "date": "2024-07-05",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 10,
#     "category": "Bar"
#   },
#   {
#     "address": "Çamlıca Tepesi, 34660 Üsküdar/Istanbul, Turkey",
#     "date": "2024-07-06",
#     "time_start": "09:00",
#     "time_end": "12:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Beyoğlu, İstiklal Cd. No: 245, 34430 Beyoğlu/Istanbul, Turkey",
#     "date": "2024-07-06",
#     "time_start": "13:00",
#     "time_end": "15:00",
#     "price": 20,
#     "category": "Museum"
#   },
#   {
#     "address": "Kadıköy, Moda Cd. No: 123, 34710 Kadıköy/Istanbul, Turkey",
#     "date": "2024-07-06",
#     "time_start": "16:00",
#     "time_end": "18:00",
#     "price": 10,
#     "category": "Bar"
#   }
# ]
#
# 49.4
# 33.33333333333333
# Total Travel Time: 595 minutes
# Activity Score: 65
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#     {
#         "address": "Museumplein 6, 1071 DJ Amsterdam, Netherlands",
#         "date": "2023-09-21",
#         "time_start": "10:00",
#         "time_end": "13:00",
#         "price": 20,
#         "category": "Art"
#     },
#     {
#         "address": "Strandzuid, Europaplein 22, 1078 GZ Amsterdam, Netherlands",
#         "date": "2023-09-21",
#         "time_start": "14:00",
#         "time_end": "17:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Dam 9, 1012 JS Amsterdam, Netherlands",
#         "date": "2023-09-21",
#         "time_start": "18:00",
#         "time_end": "20:00",
#         "price": 50,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Prinsengracht 263-267, 1016 GV Amsterdam, Netherlands",
#         "date": "2023-09-22",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 12,
#         "category": "Art"
#     },
#     {
#         "address": "IJpromenade 1, 1031 KT Amsterdam, Netherlands",
#         "date": "2023-09-22",
#         "time_start": "13:00",
#         "time_end": "15:00",
#         "price": 15,
#         "category": "Art"
#     },
#     {
#         "address": "Zuidpool, Europaplein 22, 1078 GZ Amsterdam, Netherlands",
#         "date": "2023-09-22",
#         "time_start": "16:00",
#         "time_end": "18:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Nieuwezijds Voorburgwal 176-180, 1012 SJ Amsterdam, Netherlands",
#         "date": "2023-09-22",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 60,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Oudezijds Voorburgwal 38, 1012 GD Amsterdam, Netherlands",
#         "date": "2023-09-23",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 10,
#         "category": "Art"
#     },
#     {
#         "address": "Van Baerlestraat 27, 1071 AN Amsterdam, Netherlands",
#         "date": "2023-09-23",
#         "time_start": "13:00",
#         "time_end": "15:00",
#         "price": 25,
#         "category": "Art"
#     },
#     {
#         "address": "Blijburg aan Zee, Pampuslaan 501, 1087 HP Amsterdam, Netherlands",
#         "date": "2023-09-23",
#         "time_start": "16:00",
#         "time_end": "18:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Herengracht 542-556, 1017 CG Amsterdam, Netherlands",
#         "date": "2023-09-23",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 55,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Museumstraat 1, 1071 XX Amsterdam, Netherlands",
#         "date": "2023-09-24",
#         "time_start": "10:00",
#         "time_end": "13:00",
#         "price": 19,
#         "category": "Art"
#     },
#     {
#         "address": "Wibautstraat 150, 1091 GR Amsterdam, Netherlands",
#         "date": "2023-09-24",
#         "time_start": "14:00",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Spuistraat 172, 1012 VT Amsterdam, Netherlands",
#         "date": "2023-09-24",
#         "time_start": "17:00",
#         "time_end": "19:00",
#         "price": 45,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Stadhouderskade 78, 1072 AE Amsterdam, Netherlands",
#         "date": "2023-09-25",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 18,
#         "category": "Art"
#     },
#     {
#         "address": "IJdok 4, 1013 MM Amsterdam, Netherlands",
#         "date": "2023-09-25",
#         "time_start": "13:00",
#         "time_end": "15:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Rozengracht 160, 1016 NJ Amsterdam, Netherlands",
#         "date": "2023-09-25",
#         "time_start": "16:00",
#         "time_end": "18:00",
#         "price": 50,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Keizersgracht 609, 1017 DS Amsterdam, Netherlands",
#         "date": "2023-09-26",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 11,
#         "category": "Art"
#     },
#     {
#         "address": "Amstel 51, 1018 EJ Amsterdam, Netherlands",
#         "date": "2023-09-26",
#         "time_start": "13:00",
#         "time_end": "15:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Haarlemmerstraat 73-75, 1013 EL Amsterdam, Netherlands",
#         "date": "2023-09-26",
#         "time_start": "16:00",
#         "time_end": "18:00",
#         "price": 55,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rokin 92, 1012 KZ Amsterdam, Netherlands",
#         "date": "2023-09-27",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 9,
#         "category": "Art"
#     },
#     {
#         "address": "IJburglaan 1006, 1087 EN Amsterdam, Netherlands",
#         "date": "2023-09-27",
#         "time_start": "13:00",
#         "time_end": "15:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Ferdinand Bolstraat 333, 1072 LH Amsterdam, Netherlands",
#         "date": "2023-09-27",
#         "time_start": "16:00",
#         "time_end": "18:00",
#         "price": 45,
#         "category": "Restaurants"
#     }
# ]
#
# 99.8
# 100.0
# Total Travel Time: 400 minutes
# Activity Score: 60
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#   {
#     "address": "Kurfürstendamm, 10719 Berlin, Germany",
#     "date": "2023-12-09",
#     "time_start": "10:00",
#     "time_end": "13:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Friedrichstraße, 10117 Berlin, Germany",
#     "date": "2023-12-09",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Rosenthaler Str. 40/41, 10178 Berlin, Germany",
#     "date": "2023-12-09",
#     "time_start": "18:00",
#     "time_end": "19:30",
#     "price": 15,
#     "category": "Desserts"
#   },
#   {
#     "address": "Grunewald, Berlin, Germany",
#     "date": "2023-12-10",
#     "time_start": "09:00",
#     "time_end": "13:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Alexanderplatz, 10178 Berlin, Germany",
#     "date": "2023-12-10",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Unter den Linden, 10117 Berlin, Germany",
#     "date": "2023-12-11",
#     "time_start": "10:00",
#     "time_end": "13:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Potsdamer Platz, 10785 Berlin, Germany",
#     "date": "2023-12-11",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Oranienburger Str. 32, 10117 Berlin, Germany",
#     "date": "2023-12-11",
#     "time_start": "18:00",
#     "time_end": "19:30",
#     "price": 20,
#     "category": "Desserts"
#   },
#   {
#     "address": "Müggelberge, Berlin, Germany",
#     "date": "2023-12-12",
#     "time_start": "09:00",
#     "time_end": "13:00",
#     "price": 0,
#     "category": "Hiking"
#   },
#   {
#     "address": "Schloßstraße, 12163 Berlin, Germany",
#     "date": "2023-12-12",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Tauentzienstraße 21-24, 10789 Berlin, Germany",
#     "date": "2023-12-13",
#     "time_start": "10:00",
#     "time_end": "13:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Hackescher Markt, 10178 Berlin, Germany",
#     "date": "2023-12-13",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Dessert Bar Berlin, Invalidenstraße 30, 10115 Berlin, Germany",
#     "date": "2023-12-13",
#     "time_start": "18:00",
#     "time_end": "19:30",
#     "price": 25,
#     "category": "Desserts"
#   },
#   {
#     "address": "Teufelsberg, Berlin, Germany",
#     "date": "2023-12-14",
#     "time_start": "09:00",
#     "time_end": "13:00",
#     "price": 8,
#     "category": "Hiking"
#   },
#   {
#     "address": "Bikini Berlin, Budapester Str. 38-50, 10787 Berlin, Germany",
#     "date": "2023-12-14",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Kollwitzstraße 83, 10435 Berlin, Germany",
#     "date": "2023-12-14",
#     "time_start": "18:00",
#     "time_end": "19:30",
#     "price": 12,
#     "category": "Desserts"
#   },
#   {
#     "address": "Pfaueninsel, Berlin, Germany",
#     "date": "2023-12-15",
#     "time_start": "09:00",
#     "time_end": "13:00",
#     "price": 10,
#     "category": "Hiking"
#   },
#   {
#     "address": "Mall of Berlin, Leipziger Pl. 12, 10117 Berlin, Germany",
#     "date": "2023-12-15",
#     "time_start": "14:00",
#     "time_end": "17:00",
#     "price": 0,
#     "category": "Shopping"
#   },
#   {
#     "address": "Kreuzberg, Berlin, Germany",
#     "date": "2023-12-15",
#     "time_start": "18:00",
#     "time_end": "19:30",
#     "price": 10,
#     "category": "Desserts"
#   }
# ]
#
# 20.0
# 100.0
# Total Travel Time: 396 minutes
# Activity Score: 55
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#     {
#         "address": "Plaza de la Independencia, 7, 28001 Madrid, Spain",
#         "date": "2023-10-21",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Calle de la Cava Baja, 30, 28005 Madrid, Spain",
#         "date": "2023-10-21",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 30,
#         "category": "Bars"
#     },
#     {
#         "address": "Paseo del Prado, s/n, 28014 Madrid, Spain",
#         "date": "2023-10-22",
#         "time_start": "10:00",
#         "time_end": "13:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Calle de Echegaray, 20, 28014 Madrid, Spain",
#         "date": "2023-10-22",
#         "time_start": "21:00",
#         "time_end": "00:00",
#         "price": 40,
#         "category": "Bars"
#     },
#     {
#         "address": "Calle de Serrano, 61, 28006 Madrid, Spain",
#         "date": "2023-10-23",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Calle de la Princesa, 3, 28008 Madrid, Spain",
#         "date": "2023-10-23",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 25,
#         "category": "Bars"
#     },
#     {
#         "address": "Avenida de Concha Espina, 1, 28036 Madrid, Spain",
#         "date": "2023-10-24",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Gran Vía, 12, 28013 Madrid, Spain",
#         "date": "2023-10-24",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 35,
#         "category": "Bars"
#     },
#     {
#         "address": "Calle Alcalá, 42, 28014 Madrid, Spain",
#         "date": "2023-10-25",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Calle de las Huertas, 12, 28012 Madrid, Spain",
#         "date": "2023-10-25",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 30,
#         "category": "Bars"
#     },
#     {
#         "address": "Calle de Velázquez, 34, 28001 Madrid, Spain",
#         "date": "2023-10-26",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Calle de la Montera, 10, 28013 Madrid, Spain",
#         "date": "2023-10-26",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 20,
#         "category": "Bars"
#     },
#     {
#         "address": "Calle de Alcalá, 13, 28014 Madrid, Spain",
#         "date": "2023-10-27",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Calle de la Reina, 5, 28004 Madrid, Spain",
#         "date": "2023-10-27",
#         "time_start": "20:00",
#         "time_end": "23:00",
#         "price": 25,
#         "category": "Bars"
#     }
# ]
#
# 41.0
# 66.66666666666666
# Total Travel Time: 145 minutes
# Activity Score: 100
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#     {
#         "address": "Rua Augusta, 1100-048 Lisboa, Portugal",
#         "date": "2023-07-27",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Praça do Comércio, 1100-148 Lisboa, Portugal",
#         "date": "2023-07-27",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua Garrett, 1200-203 Lisboa, Portugal",
#         "date": "2023-07-27",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 20,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Avenida da Liberdade, 1250-096 Lisboa, Portugal",
#         "date": "2023-07-27",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua Nova do Carvalho, 1200-014 Lisboa, Portugal",
#         "date": "2023-07-27",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 15,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua das Portas de Santo Antão, 1150-268 Lisboa, Portugal",
#         "date": "2023-07-27",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 30,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua da Prata, 1100-420 Lisboa, Portugal",
#         "date": "2023-07-28",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Carmo, 1200-093 Lisboa, Portugal",
#         "date": "2023-07-28",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua Jardim do Regedor, 1150-193 Lisboa, Portugal",
#         "date": "2023-07-28",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 25,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua do Ouro, 1150-060 Lisboa, Portugal",
#         "date": "2023-07-28",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua de São Bento, 1200-821 Lisboa, Portugal",
#         "date": "2023-07-28",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Salitre, 1250-198 Lisboa, Portugal",
#         "date": "2023-07-28",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 35,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua das Flores, 1200-195 Lisboa, Portugal",
#         "date": "2023-07-29",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Alecrim, 1200-017 Lisboa, Portugal",
#         "date": "2023-07-29",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua de São Nicolau, 1100-547 Lisboa, Portugal",
#         "date": "2023-07-29",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 20,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua da Escola Politécnica, 1250-102 Lisboa, Portugal",
#         "date": "2023-07-29",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua do Século, 1200-434 Lisboa, Portugal",
#         "date": "2023-07-29",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 15,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Telhal, 1150-345 Lisboa, Portugal",
#         "date": "2023-07-29",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 30,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua da Madalena, 1100-319 Lisboa, Portugal",
#         "date": "2023-07-30",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Arsenal, 1100-038 Lisboa, Portugal",
#         "date": "2023-07-30",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua de São Mamede, 1100-533 Lisboa, Portugal",
#         "date": "2023-07-30",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 25,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua do Crucifixo, 1100-182 Lisboa, Portugal",
#         "date": "2023-07-30",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua da Conceição, 1100-153 Lisboa, Portugal",
#         "date": "2023-07-30",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Benformoso, 1100-084 Lisboa, Portugal",
#         "date": "2023-07-30",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 35,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua dos Fanqueiros, 1100-232 Lisboa, Portugal",
#         "date": "2023-07-31",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua da Palma, 1100-390 Lisboa, Portugal",
#         "date": "2023-07-31",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua do Milagre de Santo António, 1100-351 Lisboa, Portugal",
#         "date": "2023-07-31",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 20,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua da Prata, 1100-420 Lisboa, Portugal",
#         "date": "2023-07-31",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua de São Julião, 1100-524 Lisboa, Portugal",
#         "date": "2023-07-31",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 15,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua da Vitória, 1100-618 Lisboa, Portugal",
#         "date": "2023-07-31",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 30,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua dos Correeiros, 1100-162 Lisboa, Portugal",
#         "date": "2023-08-01",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Comércio, 1100-150 Lisboa, Portugal",
#         "date": "2023-08-01",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua de São Nicolau, 1100-547 Lisboa, Portugal",
#         "date": "2023-08-01",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 25,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua da Madalena, 1100-319 Lisboa, Portugal",
#         "date": "2023-08-01",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua dos Bacalhoeiros, 1100-070 Lisboa, Portugal",
#         "date": "2023-08-01",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua da Conceição, 1100-153 Lisboa, Portugal",
#         "date": "2023-08-01",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 35,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua dos Douradores, 1100-206 Lisboa, Portugal",
#         "date": "2023-08-02",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 5,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua do Crucifixo, 1100-182 Lisboa, Portugal",
#         "date": "2023-08-02",
#         "time_start": "10:30",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua da Vitória, 1100-618 Lisboa, Portugal",
#         "date": "2023-08-02",
#         "time_start": "12:30",
#         "time_end": "14:00",
#         "price": 20,
#         "category": "Restaurants"
#     },
#     {
#         "address": "Rua dos Sapateiros, 1100-579 Lisboa, Portugal",
#         "date": "2023-08-02",
#         "time_start": "14:30",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Shopping"
#     },
#     {
#         "address": "Rua dos Fanqueiros, 1100-232 Lisboa, Portugal",
#         "date": "2023-08-02",
#         "time_start": "16:30",
#         "time_end": "18:00",
#         "price": 15,
#         "category": "Cafes"
#     },
#     {
#         "address": "Rua dos Correeiros, 1100-162 Lisboa, Portugal",
#         "date": "2023-08-02",
#         "time_start": "19:00",
#         "time_end": "21:00",
#         "price": 30,
#         "category": "Restaurants"
#     }
# ]
#
# 0
# 100.0
# Total Travel Time: 270 minutes
# Activity Score: 100
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#     {
#         "address": "Stadio Pier Luigi Penzo, Campo della Celestia, 30122 Venezia VE, Italy",
#         "date": "2023-08-21",
#         "time_start": "18:00",
#         "time_end": "20:00",
#         "price": 50,
#         "category": "Live Sports"
#     },
#     {
#         "address": "Parco delle Rimembranze, 30132 Venezia VE, Italy",
#         "date": "2023-08-22",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Parco San Giuliano, Via Orlanda, 30173 Venezia VE, Italy",
#         "date": "2023-08-22",
#         "time_start": "14:00",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Lido di Venezia, 30126 Venezia VE, Italy",
#         "date": "2023-08-23",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Stadio Pier Luigi Penzo, Campo della Celestia, 30122 Venezia VE, Italy",
#         "date": "2023-08-24",
#         "time_start": "18:00",
#         "time_end": "20:00",
#         "price": 50,
#         "category": "Live Sports"
#     },
#     {
#         "address": "Parco delle Rimembranze, 30132 Venezia VE, Italy",
#         "date": "2023-08-25",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Parco San Giuliano, Via Orlanda, 30173 Venezia VE, Italy",
#         "date": "2023-08-25",
#         "time_start": "14:00",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Lido di Venezia, 30126 Venezia VE, Italy",
#         "date": "2023-08-26",
#         "time_start": "10:00",
#         "time_end": "12:00",
#         "price": 0,
#         "category": "Parks"
#     },
#     {
#         "address": "Stadio Pier Luigi Penzo, Campo della Celestia, 30122 Venezia VE, Italy",
#         "date": "2023-08-27",
#         "time_start": "18:00",
#         "time_end": "20:00",
#         "price": 50,
#         "category": "Live Sports"
#     }
# ]
#
# 30.0
# 66.66666666666666
# Total Travel Time: 416 minutes
# Activity Score: 75
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)
# Cleaned response content:
# [
#     {
#         "address": "Golden Gate Bridge, San Francisco, CA 94129",
#         "date": "2023-07-02",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 0,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Fisherman's Wharf, San Francisco, CA 94133",
#         "date": "2023-07-02",
#         "time_start": "12:00",
#         "time_end": "14:00",
#         "price": 20,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Ocean Beach, San Francisco, CA 94121",
#         "date": "2023-07-02",
#         "time_start": "15:00",
#         "time_end": "17:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Blue Bottle Coffee, 66 Mint St, San Francisco, CA 94103",
#         "date": "2023-07-02",
#         "time_start": "18:00",
#         "time_end": "19:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Alcatraz Island, San Francisco, CA 94133",
#         "date": "2023-07-03",
#         "time_start": "09:00",
#         "time_end": "12:00",
#         "price": 40,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Baker Beach, San Francisco, CA 94129",
#         "date": "2023-07-03",
#         "time_start": "13:00",
#         "time_end": "15:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Sightglass Coffee, 270 7th St, San Francisco, CA 94103",
#         "date": "2023-07-03",
#         "time_start": "16:00",
#         "time_end": "17:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Lombard Street, San Francisco, CA 94133",
#         "date": "2023-07-04",
#         "time_start": "09:00",
#         "time_end": "10:00",
#         "price": 0,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Pier 39, San Francisco, CA 94133",
#         "date": "2023-07-04",
#         "time_start": "11:00",
#         "time_end": "13:00",
#         "price": 20,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Crissy Field Beach, San Francisco, CA 94129",
#         "date": "2023-07-04",
#         "time_start": "14:00",
#         "time_end": "16:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Four Barrel Coffee, 375 Valencia St, San Francisco, CA 94103",
#         "date": "2023-07-04",
#         "time_start": "17:00",
#         "time_end": "18:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Twin Peaks, San Francisco, CA 94114",
#         "date": "2023-07-05",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 0,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Sutro Baths, San Francisco, CA 94121",
#         "date": "2023-07-05",
#         "time_start": "12:00",
#         "time_end": "14:00",
#         "price": 0,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "China Beach, San Francisco, CA 94121",
#         "date": "2023-07-05",
#         "time_start": "15:00",
#         "time_end": "17:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Philz Coffee, 3101 24th St, San Francisco, CA 94110",
#         "date": "2023-07-05",
#         "time_start": "18:00",
#         "time_end": "19:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Coit Tower, 1 Telegraph Hill Blvd, San Francisco, CA 94133",
#         "date": "2023-07-06",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 10,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Palace of Fine Arts, 3601 Lyon St, San Francisco, CA 94123",
#         "date": "2023-07-06",
#         "time_start": "12:00",
#         "time_end": "14:00",
#         "price": 0,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Marshall's Beach, San Francisco, CA 94129",
#         "date": "2023-07-06",
#         "time_start": "15:00",
#         "time_end": "17:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Ritual Coffee Roasters, 1026 Valencia St, San Francisco, CA 94110",
#         "date": "2023-07-06",
#         "time_start": "18:00",
#         "time_end": "19:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "San Francisco Cable Car Museum, 1201 Mason St, San Francisco, CA 94108",
#         "date": "2023-07-07",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 8,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Ghirardelli Square, 900 North Point St, San Francisco, CA 94109",
#         "date": "2023-07-07",
#         "time_start": "12:00",
#         "time_end": "14:00",
#         "price": 15,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Aquatic Park Cove, San Francisco, CA 94109",
#         "date": "2023-07-07",
#         "time_start": "15:00",
#         "time_end": "17:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "Cafe Réveille, 201 Steiner St, San Francisco, CA 94117",
#         "date": "2023-07-07",
#         "time_start": "18:00",
#         "time_end": "19:00",
#         "price": 10,
#         "category": "Cafes"
#     },
#     {
#         "address": "Painted Ladies, Steiner St & Hayes St, San Francisco, CA 94117",
#         "date": "2023-07-08",
#         "time_start": "09:00",
#         "time_end": "11:00",
#         "price": 0,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Exploratorium, Pier 15, The Embarcadero, San Francisco, CA 94111",
#         "date": "2023-07-08",
#         "time_start": "12:00",
#         "time_end": "14:00",
#         "price": 30,
#         "category": "Sightseeing"
#     },
#     {
#         "address": "Fort Funston, San Francisco, CA 94132",
#         "date": "2023-07-08",
#         "time_start": "15:00",
#         "time_end": "17:00",
#         "price": 0,
#         "category": "Beaches"
#     },
#     {
#         "address": "The Mill, 736 Divisadero St, San Francisco, CA 94117",
#         "date": "2023-07-08",
#         "time_start": "18:00",
#         "time_end": "19:00",
#         "price": 10,
#         "category": "Cafes"
#     }
# ]
#
# 42.6
# 100.0
# Total Travel Time: 434 minutes
# Activity Score: 40
# C:\Users\river\AppData\Local\Temp\ipykernel_16664\3555640426.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_eval_metrics = df_eval_metrics.append(new_row, ignore_index=True)

# %%
df_eval_metrics
# df_eval_metrics.to_csv('scores_gpt4o_1-50', index=False)
# Out:
#     interests_score  budget_score travel_time_score         location  \
# 0         66.666667     47.333333               229          Orlando
# 1         66.666667     85.000000               158  Washington D.C.
# 2        100.000000     86.666667               139           Boston
# 3        100.000000     42.333333               107      New Orleans
# 4        100.000000     50.000000               159          Seattle
# 5         33.333333     95.000000               101         Honolulu
# 6        100.000000     66.666667                58        San Diego
# 7        100.000000    100.000000               129        Nashville
# 8        100.000000     25.000000                76           Austin
# 9        100.000000     80.666667                87     Philadelphia
# 10       100.000000     83.333333               122          Atlanta
# 11         0.000000     47.666667                64         Portland
# 12        66.666667     43.666667               129      San Antonio
# 13        66.666667      0.000000                92           Denver
# 14       100.000000     85.666667               122           Dallas
# 15         0.000000     83.333333                91      Minneapolis
# 16        66.666667     55.000000               168   Salt Lake City
# 17        66.666667     90.000000               146        Cape Town
# 18        33.333333     89.000000               216           Sydney
# 19       100.000000     92.500000               352   Rio de Janeiro
# 20         0.000000      0.000000                 0      Los Angeles
# 21        66.666667     39.750000               157         Florence
# 22       100.000000     72.500000               139           Vienna
# 23        66.666667      0.000000               190          Toronto
# 24        33.333333      0.000000               112        Melbourne
# 25       100.000000     12.000000               203     Buenos Aires
# 26       100.000000     48.750000              5052      Mexico City
# 27       100.000000     87.500000               140           Prague
# 28       100.000000      0.000000               204         Shanghai
# 29       100.000000    100.000000               342        Hong Kong
# 30       100.000000      0.000000               173          Chicago
# 31       100.000000     43.750000               159        Las Vegas
# 32        66.666667     86.000000               405            Miami
# 33       100.000000     35.000000               379            Tokyo
# 34         0.000000     72.200000               364            Paris
# 35       100.000000     86.000000               206    New York City
# 36        66.666667     59.200000               412           London
# 37       100.000000     54.800000               221             Rome
# 38       100.000000     61.000000               333          Bangkok
# 39        66.666667     51.800000               676            Dubai
# 40       100.000000      0.000000                79        Singapore
# 41       100.000000      0.000000               189        Barcelona
# 42        33.333333     49.400000               595         Istanbul
# 43       100.000000     99.800000               400        Amsterdam
# 44       100.000000     20.000000               396           Berlin
# 45        66.666667     41.000000               145           Madrid
# 46       100.000000      0.000000               270           Lisbon
# 47        66.666667     30.000000               416           Venice
# 48       100.000000     42.600000               434    San Francisco
#
#     redundency_score
# 0               75.0
# 1               75.0
# 2               70.0
# 3              100.0
# 4               75.0
# 5               75.0
# 6               75.0
# 7               75.0
# 8              100.0
# 9               85.0
# 10              75.0
# 11             100.0
# 12              75.0
# 13              75.0
# 14              75.0
# 15              65.0
# 16             100.0
# 17             100.0
# 18              75.0
# 19              70.0
# 20             100.0
# 21              65.0
# 22             100.0
# 23              55.0
# 24              75.0
# 25              70.0
# 26              70.0
# 27             100.0
# 28              55.0
# 29             100.0
# 30             100.0
# 31              70.0
# 32             100.0
# 33             100.0
# 34             100.0
# 35              85.0
# 36               0.0
# 37             100.0
# 38              65.0
# 39             100.0
# 40              85.0
# 41             100.0
# 42              65.0
# 43              60.0
# 44              55.0
# 45             100.0
# 46             100.0
# 47              75.0
# 48              40.0

# %%
sentences
# Out:
# ['Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Orlando Start date: 20-jul End Date: 22-jul Budget: 300,00 Interests: Cafes, Art, Hiking',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Washington D.C. Start date: 31-ago End Date: 2-sept Budget: 300,00 Interests: Live Sports, Desserts, Beaches',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Boston Start date: 27-oct End Date: 29-oct Budget: 300,00 Interests: Sightseeing, Bars, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: New Orleans Start date: 20-ago End Date: 22-ago Budget: 300,00 Interests: Museums, Restaurants, Parks',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Seattle Start date: 3-jul End Date: 5-jul Budget: 300,00 Interests: Art, Hiking, Cafes',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Honolulu Start date: 9-sept End Date: 11-sept Budget: 300,00 Interests: Bars, Beaches, Live Sports',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: San Diego Start date: 21-nov End Date: 23-nov Budget: 300,00 Interests: Bars, Shopping, Sightseeing',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Nashville Start date: 26-jul End Date: 28-jul Budget: 300,00 Interests: Restaurants, Parks, Museums',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Austin Start date: 20-jun End Date: 22-jun Budget: 300,00 Interests: Hiking, Cafes, Art',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Philadelphia Start date: 30-oct End Date: 1-nov Budget: 300,00 Interests: Live Sports, Desserts, Beaches',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Atlanta Start date: 2-dic End Date: 4-dic Budget: 300,00 Interests: Sightseeing, Bars, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Portland Start date: 7-nov End Date: 9-nov Budget: 300,00 Interests: Museums, Restaurants, Parks',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: San Antonio Start date: 17-ago End Date: 19-ago Budget: 300,00 Interests: Cafes, Art, Hiking',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Denver Start date: 5-sept End Date: 7-sept Budget: 300,00 Interests: Live Sports, Desserts, Beaches',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Dallas Start date: 1-nov End Date: 3-nov Budget: 300,00 Interests: Sightseeing, Bars, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Minneapolis Start date: 16-dic End Date: 18-dic Budget: 300,00 Interests: Museums, Restaurants, Parks',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Salt Lake City Start date: 20-ago End Date: 24-ago Budget: 400,00 Interests: Parks, Cafes, Beaches',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Cape Town Start date: 7-dic End Date: 11-dic Budget: 400,00 Interests: Cafes, Live Sports, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Sydney Start date: 17-ago End Date: 21-ago Budget: 400,00 Interests: Live Sports, Cafes, Parks',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Rio de Janeiro Start date: 5-oct End Date: 9-oct Budget: 400,00 Interests: Sightseeing, Live Sports, Cafes',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Los Angeles Start date: 26-jul End Date: 30-jul Budget: 400,00 Interests: Museums, Sightseeing, Hiking',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Florence Start date: 23-nov End Date: 27-nov Budget: 400,00 Interests: Art, Museums, Beaches',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Seoul Start date: 21-dic End Date: 25-dic Budget: 400,00 Interests: Cafes, Art, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Seoul Start date: 21-dic End Date: 25-dic Budget: 400,00 Interests: Cafes, Art, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Seoul Start date: 21-dic End Date: 25-dic Budget: 400,00 Interests: Cafes, Art, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Vienna Start date: 4-nov End Date: 8-nov Budget: 400,00 Interests: Live Sports, Desserts, Parks',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Toronto Start date: 24-ago End Date: 28-ago Budget: 400,00 Interests: Sightseeing, Bars, Cafes',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Melbourne Start date: 21-jun End Date: 25-jun Budget: 400,00 Interests: Museums, Restaurants, Live Sports',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Buenos Aires Start date: 20-jul End Date: 24-jul Budget: 400,00 Interests: Art, Hiking, Sightseeing',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Mexico City Start date: 3-oct End Date: 7-oct Budget: 400,00 Interests: Desserts, Beaches, Museums',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Prague Start date: 9-dic End Date: 13-dic Budget: 400,00 Interests: Bars, Shopping, Art',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Shanghai Start date: 7-ago End Date: 11-ago Budget: 400,00 Interests: Restaurants, Parks, Desserts',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Hong Kong Start date: 19-jul End Date: 23-jul Budget: 400,00 Interests: Hiking, Cafes, Bars',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Chicago Start date: 30-nov End Date: 4-dic Budget: 400,00 Interests: Beaches, Live Sports, Restaurants',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Las Vegas Start date: 21-ago End Date: 25-ago Budget: 400,00 Interests: Shopping, Sightseeing, Hiking',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Miami Start date: 25-nov End Date: 1-dic Budget: 500,00 Interests: Museums, Shopping, Live Sports',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Tokyo Start date: 7-oct End Date: 13-oct Budget: 500,00 Interests: Art, Parks, Sightseeing',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Paris Start date: 9-ago End Date: 15-ago Budget: 500,00 Interests: Cafes, Restaurants, Museums',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: New York City Start date: 28-jun End Date: 4-jul Budget: 500,00 Interests: Live Sports, Hiking, Art',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: London Start date: 20-sept End Date: 26-sept Budget: 500,00 Interests: Sightseeing, Beaches, Desserts',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Rome Start date: 6-dic End Date: 12-dic Budget: 500,00 Interests: Museums, Shopping, Bars',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Bangkok Start date: 21-oct End Date: 27-oct Budget: 500,00 Interests: Art, Parks, Restaurants',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Dubai Start date: 28-jul End Date: 3-ago Budget: 500,00 Interests: Desserts, Cafes, Hiking',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Singapore Start date: 22-nov End Date: 28-nov Budget: 500,00 Interests: Bars, Sports, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Barcelona Start date: 3-ago End Date: 9-ago Budget: 500,00 Interests: Restaurants, Sightseeing, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Istanbul Start date: 30-jun End Date: 6-jul Budget: 500,00 Interests: Hiking, Museums, Bars',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Amsterdam Start date: 21-sept End Date: 27-sept Budget: 500,00 Interests: Beaches, Art, Restaurants',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Berlin Start date: 9-dic End Date: 15-dic Budget: 500,00 Interests: Shopping, Desserts, Hiking',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Madrid Start date: 21-oct End Date: 27-oct Budget: 500,00 Interests: Parks, Bars, Beaches',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Lisbon Start date: 27-jul End Date: 2-ago Budget: 500,00 Interests: Cafes, Restaurants, Shopping',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: Venice Start date: 21-ago End Date: 27-ago Budget: 500,00 Interests: Live Sports, Hiking, Parks',
#  'Create a very busy travel plan for the following location, dates and interests. For each event or activity planned provide a category for the activity, timeframe with hours of the day from when to when the activity will take, price for the activity and address for location of the activity. Location: San Francisco Start date: 2-jul End Date: 8-jul Budget: 500,00 Interests: Sightseeing, Beaches, Cafes']

# %%
sentences
# Save the responses to a file
with open('prompts_1-50.json', 'w') as f:
    json.dump(sentences, f, indent=4)

print("prompts saved to prompts_1-50.json")
# Out:
# prompts saved to prompts_1-50.json

# %%
responses
# Out:
# [[{'address': '123 E Central Blvd, Orlando, FL 32801',
#    'date': '2023-07-20',
#    'time_start': '08:00',
#    'time_end': '09:30',
#    'price': 15,
#    'category': 'Cafe'},
#   {'address': '2416 N Mills Ave, Orlando, FL 32803',
#    'date': '2023-07-20',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '528 E Washington St, Orlando, FL 32801',
#    'date': '2023-07-20',
#    'time_start': '13:00',
#    'time_end': '14:30',
#    'price': 10,
#    'category': 'Cafe'},
#   {'address': '315 Conroy Windermere Rd, Orlando, FL 32835',
#    'date': '2023-07-20',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '12078 Collegiate Way, Orlando, FL 32817',
#    'date': '2023-07-21',
#    'time_start': '08:00',
#    'time_end': '09:30',
#    'price': 12,
#    'category': 'Cafe'},
#   {'address': '1 Jeff Fuqua Blvd, Orlando, FL 32827',
#    'date': '2023-07-21',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Art'},
#   {'address': '131 N Orange Ave, Orlando, FL 32801',
#    'date': '2023-07-21',
#    'time_start': '13:00',
#    'time_end': '14:30',
#    'price': 10,
#    'category': 'Cafe'},
#   {'address': '3401 S Hiawassee Rd, Orlando, FL 32835',
#    'date': '2023-07-21',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '558 W New England Ave, Winter Park, FL 32789',
#    'date': '2023-07-22',
#    'time_start': '08:00',
#    'time_end': '09:30',
#    'price': 18,
#    'category': 'Cafe'},
#   {'address': '2416 N Mills Ave, Orlando, FL 32803',
#    'date': '2023-07-22',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '12078 Collegiate Way, Orlando, FL 32817',
#    'date': '2023-07-22',
#    'time_start': '13:00',
#    'time_end': '14:30',
#    'price': 12,
#    'category': 'Cafe'},
#   {'address': '2851 S John Young Pkwy, Orlando, FL 32805',
#    'date': '2023-07-22',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Hiking'}],
#  [{'address': '1500 S Capitol St SE, Washington, DC 20003',
#    'date': '2023-08-31',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '800 F St NW, Washington, DC 20004',
#    'date': '2023-08-31',
#    'time_start': '17:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 International Dr, McLean, VA 22102',
#    'date': '2023-08-31',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 20,
#    'category': 'Desserts'},
#   {'address': '1500 S Capitol St SE, Washington, DC 20003',
#    'date': '2023-09-01',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '800 F St NW, Washington, DC 20004',
#    'date': '2023-09-01',
#    'time_start': '14:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 International Dr, McLean, VA 22102',
#    'date': '2023-09-01',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Desserts'},
#   {'address': '1500 S Capitol St SE, Washington, DC 20003',
#    'date': '2023-09-02',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '800 F St NW, Washington, DC 20004',
#    'date': '2023-09-02',
#    'time_start': '14:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 International Dr, McLean, VA 22102',
#    'date': '2023-09-02',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Desserts'}],
#  [{'address': '139 Tremont St, Boston, MA 02111',
#    'date': '2023-10-27',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '4 S Market St, Boston, MA 02109',
#    'date': '2023-10-27',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '206 Washington St, Boston, MA 02109',
#    'date': '2023-10-27',
#    'time_start': '13:30',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': '1 Faneuil Hall Sq, Boston, MA 02109',
#    'date': '2023-10-27',
#    'time_start': '15:30',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '82A Lansdowne St, Boston, MA 02215',
#    'date': '2023-10-27',
#    'time_start': '18:00',
#    'time_end': '21:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '200 Atlantic Ave, Boston, MA 02110',
#    'date': '2023-10-28',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '800 Boylston St, Boston, MA 02199',
#    'date': '2023-10-28',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '4 Yawkey Way, Boston, MA 02215',
#    'date': '2023-10-28',
#    'time_start': '13:30',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '1 Ashburton Pl, Boston, MA 02108',
#    'date': '2023-10-28',
#    'time_start': '15:30',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '10 Scotia St, Boston, MA 02115',
#    'date': '2023-10-28',
#    'time_start': '18:00',
#    'time_end': '21:00',
#    'price': 40,
#    'category': 'Bars'},
#   {'address': '65 Northern Ave, Boston, MA 02210',
#    'date': '2023-10-29',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '450 Harrison Ave, Boston, MA 02118',
#    'date': '2023-10-29',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '1 Science Park, Boston, MA 02114',
#    'date': '2023-10-29',
#    'time_start': '13:30',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '1 Faneuil Hall Market Pl, Boston, MA 02109',
#    'date': '2023-10-29',
#    'time_start': '15:30',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '1 Central Wharf, Boston, MA 02110',
#    'date': '2023-10-29',
#    'time_start': '18:00',
#    'time_end': '21:00',
#    'price': 45,
#    'category': 'Bars'}],
#  [{'address': '1 Collins Diboll Cir, New Orleans, LA 70124',
#    'date': '2023-08-20',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 15,
#    'category': 'Museums'},
#   {'address': '800 Decatur St, New Orleans, LA 70116',
#    'date': '2023-08-20',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': '1 Palm Dr, New Orleans, LA 70124',
#    'date': '2023-08-20',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '900 Camp St, New Orleans, LA 70130',
#    'date': '2023-08-21',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 12,
#    'category': 'Museums'},
#   {'address': '1403 Washington Ave, New Orleans, LA 70130',
#    'date': '2023-08-21',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': '6500 Magazine St, New Orleans, LA 70118',
#    'date': '2023-08-21',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '751 Chartres St, New Orleans, LA 70116',
#    'date': '2023-08-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Museums'},
#   {'address': '801 Chartres St, New Orleans, LA 70116',
#    'date': '2023-08-22',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': 'City Park, New Orleans, LA 70124',
#    'date': '2023-08-22',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Parks'}],
#  [{'address': '1300 1st Ave, Seattle, WA 98101',
#    'date': '2023-07-03',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Art'},
#   {'address': '325 5th Ave N, Seattle, WA 98109',
#    'date': '2023-07-03',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '3801 Discovery Park Blvd, Seattle, WA 98199',
#    'date': '2023-07-03',
#    'time_start': '13:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '1115 12th Ave, Seattle, WA 98122',
#    'date': '2023-07-03',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '1400 E Prospect St, Seattle, WA 98112',
#    'date': '2023-07-04',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '102 Pike St, Seattle, WA 98101',
#    'date': '2023-07-04',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Cafes'},
#   {'address': '704 Terry Ave, Seattle, WA 98104',
#    'date': '2023-07-04',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 10,
#    'category': 'Art'},
#   {'address': '860 Terry Ave N, Seattle, WA 98109',
#    'date': '2023-07-04',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '1000 4th Ave, Seattle, WA 98104',
#    'date': '2023-07-05',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': '5900 Lake Washington Blvd S, Seattle, WA 98118',
#    'date': '2023-07-05',
#    'time_start': '11:30',
#    'time_end': '14:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '1424 11th Ave, Seattle, WA 98122',
#    'date': '2023-07-05',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '305 Harrison St, Seattle, WA 98109',
#    'date': '2023-07-05',
#    'time_start': '16:30',
#    'time_end': '18:30',
#    'price': 25,
#    'category': 'Art'}],
#  [{'address': '2255 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-09',
#    'time_start': '08:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Beach'},
#   {'address': '2335 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-09',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Bar'},
#   {'address': '1201 Ala Moana Blvd, Honolulu, HI 96814',
#    'date': '2024-09-09',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '2330 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-09',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bar'},
#   {'address': '2169 Kalia Rd, Honolulu, HI 96815',
#    'date': '2024-09-10',
#    'time_start': '08:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Beach'},
#   {'address': '2259 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-10',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Bar'},
#   {'address': '1201 Ala Moana Blvd, Honolulu, HI 96814',
#    'date': '2024-09-10',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '2330 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-10',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bar'},
#   {'address': '2255 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-11',
#    'time_start': '08:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Beach'},
#   {'address': '2335 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-11',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Bar'},
#   {'address': '1201 Ala Moana Blvd, Honolulu, HI 96814',
#    'date': '2024-09-11',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '2330 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-11',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bar'}],
#  [{'address': '123 Main St, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '789 Market St, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '456 Broadway, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 15,
#    'category': 'Bars'},
#   {'address': '789 Harbor Dr, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 30,
#    'category': 'Sightseeing'},
#   {'address': '1010 Fifth Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '333 Fourth Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Shopping'},
#   {'address': '555 Sixth Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Bars'},
#   {'address': '777 Seventh Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '999 Ninth Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '1111 Tenth Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '2222 Eleventh Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Bars'},
#   {'address': '3333 Twelfth Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 25,
#    'category': 'Sightseeing'}],
#  [{'address': '2800 Opryland Dr, Nashville, TN 37214',
#    'date': '2024-07-26',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Parks'},
#   {'address': '2500 West End Ave, Nashville, TN 37203',
#    'date': '2024-07-26',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': '222 5th Ave S, Nashville, TN 37203',
#    'date': '2024-07-26',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 20,
#    'category': 'Museums'},
#   {'address': '4001 Harding Pike, Nashville, TN 37205',
#    'date': '2024-07-26',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': '1200 Forrest Park Dr, Nashville, TN 37205',
#    'date': '2024-07-27',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Parks'},
#   {'address': '401 Church St, Nashville, TN 37219',
#    'date': '2024-07-27',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': '919 Broadway, Nashville, TN 37203',
#    'date': '2024-07-27',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 15,
#    'category': 'Museums'},
#   {'address': '123 12th Ave N, Nashville, TN 37203',
#    'date': '2024-07-27',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 40,
#    'category': 'Restaurants'},
#   {'address': '3777 Nolensville Pike, Nashville, TN 37211',
#    'date': '2024-07-28',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Parks'},
#   {'address': '1526 Demonbreun St, Nashville, TN 37203',
#    'date': '2024-07-28',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': '1908 Grand Ave, Nashville, TN 37212',
#    'date': '2024-07-28',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 20,
#    'category': 'Museums'},
#   {'address': '201 8th Ave S, Nashville, TN 37203',
#    'date': '2024-07-28',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 30,
#    'category': 'Restaurants'}],
#  [{'address': '2100 Barton Springs Rd, Austin, TX 78746',
#    'date': '2023-06-20',
#    'time_start': '07:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '2001 S 1st St, Austin, TX 78704',
#    'date': '2023-06-20',
#    'time_start': '12:00',
#    'time_end': '13:30',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': '3809 W 35th St, Austin, TX 78703',
#    'date': '2023-06-20',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 10,
#    'category': 'Art'},
#   {'address': '2100 Barton Springs Rd, Austin, TX 78746',
#    'date': '2023-06-21',
#    'time_start': '07:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '1501 S 1st St, Austin, TX 78704',
#    'date': '2023-06-21',
#    'time_start': '12:00',
#    'time_end': '13:30',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': '700 Congress Ave, Austin, TX 78701',
#    'date': '2023-06-21',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '2100 Barton Springs Rd, Austin, TX 78746',
#    'date': '2023-06-22',
#    'time_start': '07:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '2200 S Lamar Blvd, Austin, TX 78704',
#    'date': '2023-06-22',
#    'time_start': '12:00',
#    'time_end': '13:30',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '512 W 29th St, Austin, TX 78705',
#    'date': '2023-06-22',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Art'}],
#  [{'address': '1 Lincoln Financial Field Way, Philadelphia, PA 19148',
#    'date': '2023-10-30',
#    'time_start': '12:00',
#    'time_end': '15:00',
#    'price': 75,
#    'category': 'Live Sports'},
#   {'address': '2101 S Broad St, Philadelphia, PA 19148',
#    'date': '2023-10-30',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '3001 Walnut St, Philadelphia, PA 19104',
#    'date': '2023-10-30',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 20,
#    'category': 'Live Sports'},
#   {'address': '401 S Christopher Columbus Blvd, Philadelphia, PA 19106',
#    'date': '2023-10-31',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': '1801 JFK Blvd, Philadelphia, PA 19103',
#    'date': '2023-10-31',
#    'time_start': '12:00',
#    'time_end': '13:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '3601 S Broad St, Philadelphia, PA 19148',
#    'date': '2023-10-31',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1 Citizens Bank Way, Philadelphia, PA 19148',
#    'date': '2023-11-01',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 60,
#    'category': 'Live Sports'},
#   {'address': '1136 Arch St, Philadelphia, PA 19107',
#    'date': '2023-11-01',
#    'time_start': '14:00',
#    'time_end': '15:00',
#    'price': 12,
#    'category': 'Desserts'},
#   {'address': '500 S Columbus Blvd, Philadelphia, PA 19106',
#    'date': '2023-11-01',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Beaches'}],
#  [{'address': '225 Baker St NW, Atlanta, GA 30313',
#    'date': '2023-12-02',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 35,
#    'category': 'Sightseeing'},
#   {'address': '121 Baker St NW, Atlanta, GA 30313',
#    'date': '2023-12-02',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-02',
#    'time_start': '14:30',
#    'time_end': '16:30',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-02',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '800 Cherokee Ave SE, Atlanta, GA 30315',
#    'date': '2023-12-03',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '1345 Piedmont Ave NE, Atlanta, GA 30309',
#    'date': '2023-12-03',
#    'time_start': '11:30',
#    'time_end': '13:30',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '3393 Peachtree Rd NE, Atlanta, GA 30326',
#    'date': '2023-12-03',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-03',
#    'time_start': '17:30',
#    'time_end': '19:30',
#    'price': 40,
#    'category': 'Bars'},
#   {'address': '130 West Paces Ferry Rd NW, Atlanta, GA 30305',
#    'date': '2023-12-04',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '1280 Peachtree St NE, Atlanta, GA 30309',
#    'date': '2023-12-04',
#    'time_start': '11:30',
#    'time_end': '13:30',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-04',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-04',
#    'time_start': '16:30',
#    'time_end': '18:30',
#    'price': 45,
#    'category': 'Bars'}],
#  [{'address': '1219 SW Park Ave, Portland, OR 97205',
#    'date': '2023-11-07',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Museum'},
#   {'address': '1200 SW Park Ave, Portland, OR 97205',
#    'date': '2023-11-07',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Restaurant'},
#   {'address': '400 SW Kingston Ave, Portland, OR 97205',
#    'date': '2023-11-07',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '1219 SW Park Ave, Portland, OR 97205',
#    'date': '2023-11-08',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Museum'},
#   {'address': '1300 SW 6th Ave, Portland, OR 97201',
#    'date': '2023-11-08',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 30,
#    'category': 'Restaurant'},
#   {'address': '400 SW Kingston Ave, Portland, OR 97205',
#    'date': '2023-11-08',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '4015 SW Canyon Rd, Portland, OR 97221',
#    'date': '2023-11-09',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 18,
#    'category': 'Museum'},
#   {'address': '410 SW Broadway, Portland, OR 97205',
#    'date': '2023-11-09',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 25,
#    'category': 'Restaurant'},
#   {'address': '6220 SE Salmon St, Portland, OR 97215',
#    'date': '2023-11-09',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Park'}],
#  [{'address': '123 Main St, San Antonio, TX 78205',
#    'date': '2023-08-17',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 10,
#    'category': 'Coffee'},
#   {'address': '200 W Jones Ave, San Antonio, TX 78215',
#    'date': '2023-08-17',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '430 E Commerce St, San Antonio, TX 78205',
#    'date': '2023-08-17',
#    'time_start': '13:00',
#    'time_end': '14:00',
#    'price': 12,
#    'category': 'Coffee'},
#   {'address': "3803 N St Mary's St, San Antonio, TX 78212",
#    'date': '2023-08-17',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '8403 NW Military Hwy, San Antonio, TX 78231',
#    'date': '2023-08-18',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '303 Pearl Pkwy, San Antonio, TX 78215',
#    'date': '2023-08-18',
#    'time_start': '11:00',
#    'time_end': '12:00',
#    'price': 10,
#    'category': 'Coffee'},
#   {'address': '200 W Jones Ave, San Antonio, TX 78215',
#    'date': '2023-08-18',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '1032 S Alamo St, San Antonio, TX 78210',
#    'date': '2023-08-18',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 12,
#    'category': 'Coffee'},
#   {'address': '8403 NW Military Hwy, San Antonio, TX 78231',
#    'date': '2023-08-19',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '303 Pearl Pkwy, San Antonio, TX 78215',
#    'date': '2023-08-19',
#    'time_start': '11:00',
#    'time_end': '12:00',
#    'price': 10,
#    'category': 'Coffee'},
#   {'address': '200 W Jones Ave, San Antonio, TX 78215',
#    'date': '2023-08-19',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '1032 S Alamo St, San Antonio, TX 78210',
#    'date': '2023-08-19',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 12,
#    'category': 'Coffee'}],
#  [{'address': '1701 Bryant St, Denver, CO 80204',
#    'date': '2023-09-05',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 60,
#    'category': 'Live Sports'},
#   {'address': '215 E 7th Ave, Denver, CO 80203',
#    'date': '2023-09-05',
#    'time_start': '17:00',
#    'time_end': '18:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '1000 Chopper Cir, Denver, CO 80204',
#    'date': '2023-09-05',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 80,
#    'category': 'Live Sports'},
#   {'address': '3030 E 2nd Ave, Denver, CO 80206',
#    'date': '2023-09-06',
#    'time_start': '10:00',
#    'time_end': '11:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 Blake St, Denver, CO 80205',
#    'date': '2023-09-06',
#    'time_start': '12:00',
#    'time_end': '15:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '500 16th St Mall, Denver, CO 80202',
#    'date': '2023-09-06',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '1000 Broadway, Denver, CO 80203',
#    'date': '2023-09-06',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 30,
#    'category': 'Live Sports'},
#   {'address': '3000 E 1st Ave, Denver, CO 80206',
#    'date': '2023-09-07',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '2000 Elitch Cir, Denver, CO 80204',
#    'date': '2023-09-07',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1201 16th St Mall, Denver, CO 80202',
#    'date': '2023-09-07',
#    'time_start': '15:00',
#    'time_end': '16:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '1000 Chopper Cir, Denver, CO 80204',
#    'date': '2023-09-07',
#    'time_start': '17:00',
#    'time_end': '20:00',
#    'price': 50,
#    'category': 'Live Sports'}],
#  [{'address': '300 Reunion Blvd E, Dallas, TX 75207',
#    'date': '2023-11-01',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '2201 N Field St, Dallas, TX 75201',
#    'date': '2023-11-01',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '8687 N Central Expy #400, Dallas, TX 75225',
#    'date': '2023-11-01',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '2821 Turtle Creek Blvd, Dallas, TX 75219',
#    'date': '2023-11-01',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '411 Elm St, Dallas, TX 75202',
#    'date': '2023-11-02',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 16,
#    'category': 'Sightseeing'},
#   {'address': '1717 N Harwood St, Dallas, TX 75201',
#    'date': '2023-11-02',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 10,
#    'category': 'Sightseeing'},
#   {'address': '8687 N Central Expy #400, Dallas, TX 75225',
#    'date': '2023-11-02',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '2821 Turtle Creek Blvd, Dallas, TX 75219',
#    'date': '2023-11-02',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '650 S Griffin St, Dallas, TX 75202',
#    'date': '2023-11-03',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '411 Elm St, Dallas, TX 75202',
#    'date': '2023-11-03',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 16,
#    'category': 'Sightseeing'},
#   {'address': '8687 N Central Expy #400, Dallas, TX 75225',
#    'date': '2023-11-03',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '2821 Turtle Creek Blvd, Dallas, TX 75219',
#    'date': '2023-11-03',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 50,
#    'category': 'Bars'}],
#  [{'address': '2400 3rd Ave S, Minneapolis, MN 55404',
#    'date': '2023-12-16',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Museum'},
#   {'address': '300 Washington Ave SE, Minneapolis, MN 55455',
#    'date': '2023-12-16',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 0,
#    'category': 'Museum'},
#   {'address': '1300 Nicollet Mall, Minneapolis, MN 55403',
#    'date': '2023-12-16',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 50,
#    'category': 'Restaurant'},
#   {'address': '725 Vineland Pl, Minneapolis, MN 55403',
#    'date': '2023-12-17',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Museum'},
#   {'address': '2000 3rd Ave S, Minneapolis, MN 55404',
#    'date': '2023-12-17',
#    'time_start': '12:30',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Museum'},
#   {'address': '3000 E Calhoun Pkwy, Minneapolis, MN 55408',
#    'date': '2023-12-17',
#    'time_start': '15:30',
#    'time_end': '17:30',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '1601 W Lake St, Minneapolis, MN 55408',
#    'date': '2023-12-17',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 60,
#    'category': 'Restaurant'},
#   {'address': '725 Vineland Pl, Minneapolis, MN 55403',
#    'date': '2023-12-18',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '3500 W 44th St, Minneapolis, MN 55410',
#    'date': '2023-12-18',
#    'time_start': '11:30',
#    'time_end': '13:30',
#    'price': 30,
#    'category': 'Restaurant'},
#   {'address': '725 Vineland Pl, Minneapolis, MN 55403',
#    'date': '2023-12-18',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 20,
#    'category': 'Museum'},
#   {'address': '1 Portland Ave, Minneapolis, MN 55401',
#    'date': '2023-12-18',
#    'time_start': '16:30',
#    'time_end': '18:30',
#    'price': 30,
#    'category': 'Restaurant'}],
#  [{'address': '350 N State St, Salt Lake City, UT 84114',
#    'date': '2023-08-20',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '122 Main St, Salt Lake City, UT 84101',
#    'date': '2023-08-20',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '200 S 74 E, Salt Lake City, UT 84101',
#    'date': '2023-08-20',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 10,
#    'category': 'Parks'},
#   {'address': '1235 E Wilmington Ave, Salt Lake City, UT 84106',
#    'date': '2023-08-20',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Cafes'},
#   {'address': '650 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-21',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 5,
#    'category': 'Parks'},
#   {'address': '902 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-21',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 12,
#    'category': 'Cafes'},
#   {'address': '300 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-21',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 8,
#    'category': 'Parks'},
#   {'address': '1100 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-21',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 18,
#    'category': 'Cafes'},
#   {'address': '2000 E 3300 S, Salt Lake City, UT 84109',
#    'date': '2023-08-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '376 E 400 S, Salt Lake City, UT 84111',
#    'date': '2023-08-22',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 14,
#    'category': 'Cafes'},
#   {'address': '1060 S 900 W, Salt Lake City, UT 84104',
#    'date': '2023-08-22',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 7,
#    'category': 'Parks'},
#   {'address': '200 S Central Campus Dr, Salt Lake City, UT 84112',
#    'date': '2023-08-22',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 22,
#    'category': 'Cafes'},
#   {'address': '300 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-23',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 5,
#    'category': 'Parks'},
#   {'address': '902 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-23',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 12,
#    'category': 'Cafes'},
#   {'address': '300 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-23',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 8,
#    'category': 'Parks'},
#   {'address': '1100 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-23',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 18,
#    'category': 'Cafes'},
#   {'address': '650 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-24',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 5,
#    'category': 'Parks'},
#   {'address': '376 E 400 S, Salt Lake City, UT 84111',
#    'date': '2023-08-24',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 14,
#    'category': 'Cafes'},
#   {'address': '200 S Central Campus Dr, Salt Lake City, UT 84112',
#    'date': '2023-08-24',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 7,
#    'category': 'Parks'},
#   {'address': '1235 E Wilmington Ave, Salt Lake City, UT 84106',
#    'date': '2023-08-24',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Cafes'}],
#  [{'address': '123 Kloof Street, Cape Town, 8001',
#    'date': '2023-12-07',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafe'},
#   {'address': '37 Buitenkant Street, Cape Town, 8000',
#    'date': '2023-12-07',
#    'time_start': '11:00',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '15 Newlands Avenue, Newlands, Cape Town, 7700',
#    'date': '2023-12-07',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 30,
#    'category': 'Live Sports'},
#   {'address': '45 Long Street, Cape Town, 8000',
#    'date': '2023-12-08',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 7,
#    'category': 'Cafe'},
#   {'address': 'Dock Road, V&A Waterfront, Cape Town, 8001',
#    'date': '2023-12-08',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Shopping'},
#   {'address': 'V&A Waterfront, Cape Town, 8001',
#    'date': '2023-12-08',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 35,
#    'category': 'Live Sports'},
#   {'address': '78 Bree Street, Cape Town, 8001',
#    'date': '2023-12-09',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 6,
#    'category': 'Cafe'},
#   {'address': 'Victoria Wharf Shopping Centre, Cape Town, 8001',
#    'date': '2023-12-09',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 30,
#    'category': 'Shopping'},
#   {'address': 'Cape Town Stadium, Fritz Sonnenberg Rd, Green Point, Cape Town, 8051',
#    'date': '2023-12-09',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 40,
#    'category': 'Live Sports'},
#   {'address': '21 Loop Street, Cape Town, 8001',
#    'date': '2023-12-10',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 8,
#    'category': 'Cafe'},
#   {'address': 'Canal Walk Shopping Centre, Century Blvd, Century City, Cape Town, 7441',
#    'date': '2023-12-10',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 35,
#    'category': 'Shopping'},
#   {'address': 'Newlands Rugby Stadium, 8 Boundary Rd, Newlands, Cape Town, 7700',
#    'date': '2023-12-10',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': '98 Kloof Street, Cape Town, 8001',
#    'date': '2023-12-11',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 6,
#    'category': 'Cafe'},
#   {'address': 'Cavendish Square, Dreyer St, Claremont, Cape Town, 7708',
#    'date': '2023-12-11',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 28,
#    'category': 'Shopping'},
#   {'address': 'Cape Town Stadium, Fritz Sonnenberg Rd, Green Point, Cape Town, 8051',
#    'date': '2023-12-11',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 40,
#    'category': 'Live Sports'}],
#  [{'address': '140 George St, The Rocks NSW 2000, Australia',
#    'date': '2023-08-17',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 15,
#    'category': 'Cafe'},
#   {'address': 'Mrs Macquaries Rd, Sydney NSW 2000, Australia',
#    'date': '2023-08-17',
#    'time_start': '09:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Driver Ave, Moore Park NSW 2021, Australia',
#    'date': '2023-08-17',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1 Martin Pl, Sydney NSW 2000, Australia',
#    'date': '2023-08-17',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 20,
#    'category': 'Cafe'},
#   {'address': 'Bradleys Head Rd, Mosman NSW 2088, Australia',
#    'date': '2023-08-18',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Lang Rd, Moore Park NSW 2021, Australia',
#    'date': '2023-08-18',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': '10 Macquarie St, Sydney NSW 2000, Australia',
#    'date': '2023-08-18',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 18,
#    'category': 'Cafe'},
#   {'address': 'Darling Harbour, Sydney NSW 2000, Australia',
#    'date': '2023-08-19',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '1 Olympic Blvd, Sydney Olympic Park NSW 2127, Australia',
#    'date': '2023-08-19',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 55,
#    'category': 'Live Sports'},
#   {'address': '500 George St, Sydney NSW 2000, Australia',
#    'date': '2023-08-19',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Cafe'},
#   {'address': 'Mrs Macquaries Rd, Sydney NSW 2000, Australia',
#    'date': '2023-08-20',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Driver Ave, Moore Park NSW 2021, Australia',
#    'date': '2023-08-20',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1 Martin Pl, Sydney NSW 2000, Australia',
#    'date': '2023-08-20',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Cafe'},
#   {'address': 'Bradleys Head Rd, Mosman NSW 2088, Australia',
#    'date': '2023-08-21',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Lang Rd, Moore Park NSW 2021, Australia',
#    'date': '2023-08-21',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': '10 Macquarie St, Sydney NSW 2000, Australia',
#    'date': '2023-08-21',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 18,
#    'category': 'Cafe'}],
#  [{'address': 'Estr. da Canoa, 3300 - São Conrado, Rio de Janeiro - RJ, 22610-210, Brazil',
#    'date': '2023-10-05',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Atlântica, Copacabana, Rio de Janeiro - RJ, 22010-000, Brazil',
#    'date': '2023-10-05',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'R. Jardim Botânico, 1008 - Jardim Botânico, Rio de Janeiro - RJ, 22460-000, Brazil',
#    'date': '2023-10-05',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Borges de Medeiros, 997 - Lagoa, Rio de Janeiro - RJ, 22470-000, Brazil',
#    'date': '2023-10-06',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Maracanã, Rio de Janeiro - RJ, 20271-110, Brazil',
#    'date': '2023-10-06',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': 'R. Dias Ferreira, 679 - Leblon, Rio de Janeiro - RJ, 22431-050, Brazil',
#    'date': '2023-10-06',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 20,
#    'category': 'Cafes'},
#   {'address': 'Praça Mauá, 1 - Centro, Rio de Janeiro - RJ, 20081-240, Brazil',
#    'date': '2023-10-07',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 30,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Atlântica, Copacabana, Rio de Janeiro - RJ, 22010-000, Brazil',
#    'date': '2023-10-07',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'R. Marquês de São Vicente, 52 - Gávea, Rio de Janeiro - RJ, 22451-040, Brazil',
#    'date': '2023-10-07',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': 'Estr. do Pontal, 3295 - Recreio dos Bandeirantes, Rio de Janeiro - RJ, 22790-877, Brazil',
#    'date': '2023-10-08',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': 'R. Visconde de Caravelas, 113 - Botafogo, Rio de Janeiro - RJ, 22271-041, Brazil',
#    'date': '2023-10-08',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Av. Vieira Souto, 110 - Ipanema, Rio de Janeiro - RJ, 22420-000, Brazil',
#    'date': '2023-10-08',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Presidente Vargas, 2000 - Centro, Rio de Janeiro - RJ, 20210-030, Brazil',
#    'date': '2023-10-09',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': 'R. do Lavradio, 132 - Centro, Rio de Janeiro - RJ, 20230-070, Brazil',
#    'date': '2023-10-09',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'Av. Maracanã, Rio de Janeiro - RJ, 20271-110, Brazil',
#    'date': '2023-10-09',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'}]]

# %%
# Save the responses to a file
with open('responses_gpt4_1-50.json', 'w') as f:
    json.dump(responses, f, indent=4)

print("Responses saved to responses.json")
# Out:
# Responses saved to responses.json

# %%
responses
# Out:
# [[{'address': '123 E Central Blvd, Orlando, FL 32801',
#    'date': '2023-07-20',
#    'time_start': '08:00',
#    'time_end': '09:30',
#    'price': 15,
#    'category': 'Cafe'},
#   {'address': '2416 N Mills Ave, Orlando, FL 32803',
#    'date': '2023-07-20',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '528 E Washington St, Orlando, FL 32801',
#    'date': '2023-07-20',
#    'time_start': '13:00',
#    'time_end': '14:30',
#    'price': 10,
#    'category': 'Cafe'},
#   {'address': '315 Conroy Windermere Rd, Orlando, FL 32835',
#    'date': '2023-07-20',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '12078 Collegiate Way, Orlando, FL 32817',
#    'date': '2023-07-21',
#    'time_start': '08:00',
#    'time_end': '09:30',
#    'price': 12,
#    'category': 'Cafe'},
#   {'address': '1 Jeff Fuqua Blvd, Orlando, FL 32827',
#    'date': '2023-07-21',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Art'},
#   {'address': '131 N Orange Ave, Orlando, FL 32801',
#    'date': '2023-07-21',
#    'time_start': '13:00',
#    'time_end': '14:30',
#    'price': 10,
#    'category': 'Cafe'},
#   {'address': '3401 S Hiawassee Rd, Orlando, FL 32835',
#    'date': '2023-07-21',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '558 W New England Ave, Winter Park, FL 32789',
#    'date': '2023-07-22',
#    'time_start': '08:00',
#    'time_end': '09:30',
#    'price': 18,
#    'category': 'Cafe'},
#   {'address': '2416 N Mills Ave, Orlando, FL 32803',
#    'date': '2023-07-22',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '12078 Collegiate Way, Orlando, FL 32817',
#    'date': '2023-07-22',
#    'time_start': '13:00',
#    'time_end': '14:30',
#    'price': 12,
#    'category': 'Cafe'},
#   {'address': '2851 S John Young Pkwy, Orlando, FL 32805',
#    'date': '2023-07-22',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Hiking'}],
#  [{'address': '1500 S Capitol St SE, Washington, DC 20003',
#    'date': '2023-08-31',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '800 F St NW, Washington, DC 20004',
#    'date': '2023-08-31',
#    'time_start': '17:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 International Dr, McLean, VA 22102',
#    'date': '2023-08-31',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 20,
#    'category': 'Desserts'},
#   {'address': '1500 S Capitol St SE, Washington, DC 20003',
#    'date': '2023-09-01',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '800 F St NW, Washington, DC 20004',
#    'date': '2023-09-01',
#    'time_start': '14:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 International Dr, McLean, VA 22102',
#    'date': '2023-09-01',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Desserts'},
#   {'address': '1500 S Capitol St SE, Washington, DC 20003',
#    'date': '2023-09-02',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '800 F St NW, Washington, DC 20004',
#    'date': '2023-09-02',
#    'time_start': '14:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 International Dr, McLean, VA 22102',
#    'date': '2023-09-02',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Desserts'}],
#  [{'address': '139 Tremont St, Boston, MA 02111',
#    'date': '2023-10-27',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '4 S Market St, Boston, MA 02109',
#    'date': '2023-10-27',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '206 Washington St, Boston, MA 02109',
#    'date': '2023-10-27',
#    'time_start': '13:30',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': '1 Faneuil Hall Sq, Boston, MA 02109',
#    'date': '2023-10-27',
#    'time_start': '15:30',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '82A Lansdowne St, Boston, MA 02215',
#    'date': '2023-10-27',
#    'time_start': '18:00',
#    'time_end': '21:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '200 Atlantic Ave, Boston, MA 02110',
#    'date': '2023-10-28',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '800 Boylston St, Boston, MA 02199',
#    'date': '2023-10-28',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '4 Yawkey Way, Boston, MA 02215',
#    'date': '2023-10-28',
#    'time_start': '13:30',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '1 Ashburton Pl, Boston, MA 02108',
#    'date': '2023-10-28',
#    'time_start': '15:30',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '10 Scotia St, Boston, MA 02115',
#    'date': '2023-10-28',
#    'time_start': '18:00',
#    'time_end': '21:00',
#    'price': 40,
#    'category': 'Bars'},
#   {'address': '65 Northern Ave, Boston, MA 02210',
#    'date': '2023-10-29',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '450 Harrison Ave, Boston, MA 02118',
#    'date': '2023-10-29',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '1 Science Park, Boston, MA 02114',
#    'date': '2023-10-29',
#    'time_start': '13:30',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '1 Faneuil Hall Market Pl, Boston, MA 02109',
#    'date': '2023-10-29',
#    'time_start': '15:30',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '1 Central Wharf, Boston, MA 02110',
#    'date': '2023-10-29',
#    'time_start': '18:00',
#    'time_end': '21:00',
#    'price': 45,
#    'category': 'Bars'}],
#  [{'address': '1 Collins Diboll Cir, New Orleans, LA 70124',
#    'date': '2023-08-20',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 15,
#    'category': 'Museums'},
#   {'address': '800 Decatur St, New Orleans, LA 70116',
#    'date': '2023-08-20',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': '1 Palm Dr, New Orleans, LA 70124',
#    'date': '2023-08-20',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '900 Camp St, New Orleans, LA 70130',
#    'date': '2023-08-21',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 12,
#    'category': 'Museums'},
#   {'address': '1403 Washington Ave, New Orleans, LA 70130',
#    'date': '2023-08-21',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': '6500 Magazine St, New Orleans, LA 70118',
#    'date': '2023-08-21',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '751 Chartres St, New Orleans, LA 70116',
#    'date': '2023-08-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Museums'},
#   {'address': '801 Chartres St, New Orleans, LA 70116',
#    'date': '2023-08-22',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': 'City Park, New Orleans, LA 70124',
#    'date': '2023-08-22',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Parks'}],
#  [{'address': '1300 1st Ave, Seattle, WA 98101',
#    'date': '2023-07-03',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Art'},
#   {'address': '325 5th Ave N, Seattle, WA 98109',
#    'date': '2023-07-03',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '3801 Discovery Park Blvd, Seattle, WA 98199',
#    'date': '2023-07-03',
#    'time_start': '13:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '1115 12th Ave, Seattle, WA 98122',
#    'date': '2023-07-03',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '1400 E Prospect St, Seattle, WA 98112',
#    'date': '2023-07-04',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '102 Pike St, Seattle, WA 98101',
#    'date': '2023-07-04',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Cafes'},
#   {'address': '704 Terry Ave, Seattle, WA 98104',
#    'date': '2023-07-04',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 10,
#    'category': 'Art'},
#   {'address': '860 Terry Ave N, Seattle, WA 98109',
#    'date': '2023-07-04',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '1000 4th Ave, Seattle, WA 98104',
#    'date': '2023-07-05',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': '5900 Lake Washington Blvd S, Seattle, WA 98118',
#    'date': '2023-07-05',
#    'time_start': '11:30',
#    'time_end': '14:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '1424 11th Ave, Seattle, WA 98122',
#    'date': '2023-07-05',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '305 Harrison St, Seattle, WA 98109',
#    'date': '2023-07-05',
#    'time_start': '16:30',
#    'time_end': '18:30',
#    'price': 25,
#    'category': 'Art'}],
#  [{'address': '2255 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-09',
#    'time_start': '08:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Beach'},
#   {'address': '2335 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-09',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Bar'},
#   {'address': '1201 Ala Moana Blvd, Honolulu, HI 96814',
#    'date': '2024-09-09',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '2330 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-09',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bar'},
#   {'address': '2169 Kalia Rd, Honolulu, HI 96815',
#    'date': '2024-09-10',
#    'time_start': '08:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Beach'},
#   {'address': '2259 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-10',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Bar'},
#   {'address': '1201 Ala Moana Blvd, Honolulu, HI 96814',
#    'date': '2024-09-10',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '2330 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-10',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bar'},
#   {'address': '2255 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-11',
#    'time_start': '08:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Beach'},
#   {'address': '2335 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-11',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 20,
#    'category': 'Bar'},
#   {'address': '1201 Ala Moana Blvd, Honolulu, HI 96814',
#    'date': '2024-09-11',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '2330 Kalakaua Ave, Honolulu, HI 96815',
#    'date': '2024-09-11',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bar'}],
#  [{'address': '123 Main St, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '789 Market St, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '456 Broadway, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 15,
#    'category': 'Bars'},
#   {'address': '789 Harbor Dr, San Diego, CA 92101',
#    'date': '2023-11-21',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 30,
#    'category': 'Sightseeing'},
#   {'address': '1010 Fifth Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '333 Fourth Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Shopping'},
#   {'address': '555 Sixth Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Bars'},
#   {'address': '777 Seventh Ave, San Diego, CA 92101',
#    'date': '2023-11-22',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '999 Ninth Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '1111 Tenth Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '2222 Eleventh Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Bars'},
#   {'address': '3333 Twelfth Ave, San Diego, CA 92101',
#    'date': '2023-11-23',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 25,
#    'category': 'Sightseeing'}],
#  [{'address': '2800 Opryland Dr, Nashville, TN 37214',
#    'date': '2024-07-26',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Parks'},
#   {'address': '2500 West End Ave, Nashville, TN 37203',
#    'date': '2024-07-26',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': '222 5th Ave S, Nashville, TN 37203',
#    'date': '2024-07-26',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 20,
#    'category': 'Museums'},
#   {'address': '4001 Harding Pike, Nashville, TN 37205',
#    'date': '2024-07-26',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': '1200 Forrest Park Dr, Nashville, TN 37205',
#    'date': '2024-07-27',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Parks'},
#   {'address': '401 Church St, Nashville, TN 37219',
#    'date': '2024-07-27',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': '919 Broadway, Nashville, TN 37203',
#    'date': '2024-07-27',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 15,
#    'category': 'Museums'},
#   {'address': '123 12th Ave N, Nashville, TN 37203',
#    'date': '2024-07-27',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 40,
#    'category': 'Restaurants'},
#   {'address': '3777 Nolensville Pike, Nashville, TN 37211',
#    'date': '2024-07-28',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Parks'},
#   {'address': '1526 Demonbreun St, Nashville, TN 37203',
#    'date': '2024-07-28',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': '1908 Grand Ave, Nashville, TN 37212',
#    'date': '2024-07-28',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 20,
#    'category': 'Museums'},
#   {'address': '201 8th Ave S, Nashville, TN 37203',
#    'date': '2024-07-28',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 30,
#    'category': 'Restaurants'}],
#  [{'address': '2100 Barton Springs Rd, Austin, TX 78746',
#    'date': '2023-06-20',
#    'time_start': '07:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '2001 S 1st St, Austin, TX 78704',
#    'date': '2023-06-20',
#    'time_start': '12:00',
#    'time_end': '13:30',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': '3809 W 35th St, Austin, TX 78703',
#    'date': '2023-06-20',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 10,
#    'category': 'Art'},
#   {'address': '2100 Barton Springs Rd, Austin, TX 78746',
#    'date': '2023-06-21',
#    'time_start': '07:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '1501 S 1st St, Austin, TX 78704',
#    'date': '2023-06-21',
#    'time_start': '12:00',
#    'time_end': '13:30',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': '700 Congress Ave, Austin, TX 78701',
#    'date': '2023-06-21',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '2100 Barton Springs Rd, Austin, TX 78746',
#    'date': '2023-06-22',
#    'time_start': '07:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '2200 S Lamar Blvd, Austin, TX 78704',
#    'date': '2023-06-22',
#    'time_start': '12:00',
#    'time_end': '13:30',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '512 W 29th St, Austin, TX 78705',
#    'date': '2023-06-22',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Art'}],
#  [{'address': '1 Lincoln Financial Field Way, Philadelphia, PA 19148',
#    'date': '2023-10-30',
#    'time_start': '12:00',
#    'time_end': '15:00',
#    'price': 75,
#    'category': 'Live Sports'},
#   {'address': '2101 S Broad St, Philadelphia, PA 19148',
#    'date': '2023-10-30',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '3001 Walnut St, Philadelphia, PA 19104',
#    'date': '2023-10-30',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 20,
#    'category': 'Live Sports'},
#   {'address': '401 S Christopher Columbus Blvd, Philadelphia, PA 19106',
#    'date': '2023-10-31',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': '1801 JFK Blvd, Philadelphia, PA 19103',
#    'date': '2023-10-31',
#    'time_start': '12:00',
#    'time_end': '13:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '3601 S Broad St, Philadelphia, PA 19148',
#    'date': '2023-10-31',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1 Citizens Bank Way, Philadelphia, PA 19148',
#    'date': '2023-11-01',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 60,
#    'category': 'Live Sports'},
#   {'address': '1136 Arch St, Philadelphia, PA 19107',
#    'date': '2023-11-01',
#    'time_start': '14:00',
#    'time_end': '15:00',
#    'price': 12,
#    'category': 'Desserts'},
#   {'address': '500 S Columbus Blvd, Philadelphia, PA 19106',
#    'date': '2023-11-01',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Beaches'}],
#  [{'address': '225 Baker St NW, Atlanta, GA 30313',
#    'date': '2023-12-02',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 35,
#    'category': 'Sightseeing'},
#   {'address': '121 Baker St NW, Atlanta, GA 30313',
#    'date': '2023-12-02',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-02',
#    'time_start': '14:30',
#    'time_end': '16:30',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-02',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '800 Cherokee Ave SE, Atlanta, GA 30315',
#    'date': '2023-12-03',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': '1345 Piedmont Ave NE, Atlanta, GA 30309',
#    'date': '2023-12-03',
#    'time_start': '11:30',
#    'time_end': '13:30',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '3393 Peachtree Rd NE, Atlanta, GA 30326',
#    'date': '2023-12-03',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-03',
#    'time_start': '17:30',
#    'time_end': '19:30',
#    'price': 40,
#    'category': 'Bars'},
#   {'address': '130 West Paces Ferry Rd NW, Atlanta, GA 30305',
#    'date': '2023-12-04',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '1280 Peachtree St NE, Atlanta, GA 30309',
#    'date': '2023-12-04',
#    'time_start': '11:30',
#    'time_end': '13:30',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-04',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '675 Ponce De Leon Ave NE, Atlanta, GA 30308',
#    'date': '2023-12-04',
#    'time_start': '16:30',
#    'time_end': '18:30',
#    'price': 45,
#    'category': 'Bars'}],
#  [{'address': '1219 SW Park Ave, Portland, OR 97205',
#    'date': '2023-11-07',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Museum'},
#   {'address': '1200 SW Park Ave, Portland, OR 97205',
#    'date': '2023-11-07',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Restaurant'},
#   {'address': '400 SW Kingston Ave, Portland, OR 97205',
#    'date': '2023-11-07',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '1219 SW Park Ave, Portland, OR 97205',
#    'date': '2023-11-08',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Museum'},
#   {'address': '1300 SW 6th Ave, Portland, OR 97201',
#    'date': '2023-11-08',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 30,
#    'category': 'Restaurant'},
#   {'address': '400 SW Kingston Ave, Portland, OR 97205',
#    'date': '2023-11-08',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '4015 SW Canyon Rd, Portland, OR 97221',
#    'date': '2023-11-09',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 18,
#    'category': 'Museum'},
#   {'address': '410 SW Broadway, Portland, OR 97205',
#    'date': '2023-11-09',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 25,
#    'category': 'Restaurant'},
#   {'address': '6220 SE Salmon St, Portland, OR 97215',
#    'date': '2023-11-09',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Park'}],
#  [{'address': '123 Main St, San Antonio, TX 78205',
#    'date': '2023-08-17',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 10,
#    'category': 'Coffee'},
#   {'address': '200 W Jones Ave, San Antonio, TX 78215',
#    'date': '2023-08-17',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '430 E Commerce St, San Antonio, TX 78205',
#    'date': '2023-08-17',
#    'time_start': '13:00',
#    'time_end': '14:00',
#    'price': 12,
#    'category': 'Coffee'},
#   {'address': "3803 N St Mary's St, San Antonio, TX 78212",
#    'date': '2023-08-17',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '8403 NW Military Hwy, San Antonio, TX 78231',
#    'date': '2023-08-18',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '303 Pearl Pkwy, San Antonio, TX 78215',
#    'date': '2023-08-18',
#    'time_start': '11:00',
#    'time_end': '12:00',
#    'price': 10,
#    'category': 'Coffee'},
#   {'address': '200 W Jones Ave, San Antonio, TX 78215',
#    'date': '2023-08-18',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '1032 S Alamo St, San Antonio, TX 78210',
#    'date': '2023-08-18',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 12,
#    'category': 'Coffee'},
#   {'address': '8403 NW Military Hwy, San Antonio, TX 78231',
#    'date': '2023-08-19',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Hiking'},
#   {'address': '303 Pearl Pkwy, San Antonio, TX 78215',
#    'date': '2023-08-19',
#    'time_start': '11:00',
#    'time_end': '12:00',
#    'price': 10,
#    'category': 'Coffee'},
#   {'address': '200 W Jones Ave, San Antonio, TX 78215',
#    'date': '2023-08-19',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': '1032 S Alamo St, San Antonio, TX 78210',
#    'date': '2023-08-19',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 12,
#    'category': 'Coffee'}],
#  [{'address': '1701 Bryant St, Denver, CO 80204',
#    'date': '2023-09-05',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 60,
#    'category': 'Live Sports'},
#   {'address': '215 E 7th Ave, Denver, CO 80203',
#    'date': '2023-09-05',
#    'time_start': '17:00',
#    'time_end': '18:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '1000 Chopper Cir, Denver, CO 80204',
#    'date': '2023-09-05',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 80,
#    'category': 'Live Sports'},
#   {'address': '3030 E 2nd Ave, Denver, CO 80206',
#    'date': '2023-09-06',
#    'time_start': '10:00',
#    'time_end': '11:00',
#    'price': 15,
#    'category': 'Desserts'},
#   {'address': '2001 Blake St, Denver, CO 80205',
#    'date': '2023-09-06',
#    'time_start': '12:00',
#    'time_end': '15:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '500 16th St Mall, Denver, CO 80202',
#    'date': '2023-09-06',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '1000 Broadway, Denver, CO 80203',
#    'date': '2023-09-06',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 30,
#    'category': 'Live Sports'},
#   {'address': '3000 E 1st Ave, Denver, CO 80206',
#    'date': '2023-09-07',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '2000 Elitch Cir, Denver, CO 80204',
#    'date': '2023-09-07',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1201 16th St Mall, Denver, CO 80202',
#    'date': '2023-09-07',
#    'time_start': '15:00',
#    'time_end': '16:00',
#    'price': 10,
#    'category': 'Desserts'},
#   {'address': '1000 Chopper Cir, Denver, CO 80204',
#    'date': '2023-09-07',
#    'time_start': '17:00',
#    'time_end': '20:00',
#    'price': 50,
#    'category': 'Live Sports'}],
#  [{'address': '300 Reunion Blvd E, Dallas, TX 75207',
#    'date': '2023-11-01',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '2201 N Field St, Dallas, TX 75201',
#    'date': '2023-11-01',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': '8687 N Central Expy #400, Dallas, TX 75225',
#    'date': '2023-11-01',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '2821 Turtle Creek Blvd, Dallas, TX 75219',
#    'date': '2023-11-01',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '411 Elm St, Dallas, TX 75202',
#    'date': '2023-11-02',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 16,
#    'category': 'Sightseeing'},
#   {'address': '1717 N Harwood St, Dallas, TX 75201',
#    'date': '2023-11-02',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 10,
#    'category': 'Sightseeing'},
#   {'address': '8687 N Central Expy #400, Dallas, TX 75225',
#    'date': '2023-11-02',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '2821 Turtle Creek Blvd, Dallas, TX 75219',
#    'date': '2023-11-02',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 50,
#    'category': 'Bars'},
#   {'address': '650 S Griffin St, Dallas, TX 75202',
#    'date': '2023-11-03',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': '411 Elm St, Dallas, TX 75202',
#    'date': '2023-11-03',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 16,
#    'category': 'Sightseeing'},
#   {'address': '8687 N Central Expy #400, Dallas, TX 75225',
#    'date': '2023-11-03',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': '2821 Turtle Creek Blvd, Dallas, TX 75219',
#    'date': '2023-11-03',
#    'time_start': '19:00',
#    'time_end': '22:00',
#    'price': 50,
#    'category': 'Bars'}],
#  [{'address': '2400 3rd Ave S, Minneapolis, MN 55404',
#    'date': '2023-12-16',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Museum'},
#   {'address': '300 Washington Ave SE, Minneapolis, MN 55455',
#    'date': '2023-12-16',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 0,
#    'category': 'Museum'},
#   {'address': '1300 Nicollet Mall, Minneapolis, MN 55403',
#    'date': '2023-12-16',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 50,
#    'category': 'Restaurant'},
#   {'address': '725 Vineland Pl, Minneapolis, MN 55403',
#    'date': '2023-12-17',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Museum'},
#   {'address': '2000 3rd Ave S, Minneapolis, MN 55404',
#    'date': '2023-12-17',
#    'time_start': '12:30',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Museum'},
#   {'address': '3000 E Calhoun Pkwy, Minneapolis, MN 55408',
#    'date': '2023-12-17',
#    'time_start': '15:30',
#    'time_end': '17:30',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '1601 W Lake St, Minneapolis, MN 55408',
#    'date': '2023-12-17',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 60,
#    'category': 'Restaurant'},
#   {'address': '725 Vineland Pl, Minneapolis, MN 55403',
#    'date': '2023-12-18',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '3500 W 44th St, Minneapolis, MN 55410',
#    'date': '2023-12-18',
#    'time_start': '11:30',
#    'time_end': '13:30',
#    'price': 30,
#    'category': 'Restaurant'},
#   {'address': '725 Vineland Pl, Minneapolis, MN 55403',
#    'date': '2023-12-18',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 20,
#    'category': 'Museum'},
#   {'address': '1 Portland Ave, Minneapolis, MN 55401',
#    'date': '2023-12-18',
#    'time_start': '16:30',
#    'time_end': '18:30',
#    'price': 30,
#    'category': 'Restaurant'}],
#  [{'address': '350 N State St, Salt Lake City, UT 84114',
#    'date': '2023-08-20',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '122 Main St, Salt Lake City, UT 84101',
#    'date': '2023-08-20',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '200 S 74 E, Salt Lake City, UT 84101',
#    'date': '2023-08-20',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 10,
#    'category': 'Parks'},
#   {'address': '1235 E Wilmington Ave, Salt Lake City, UT 84106',
#    'date': '2023-08-20',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Cafes'},
#   {'address': '650 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-21',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 5,
#    'category': 'Parks'},
#   {'address': '902 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-21',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 12,
#    'category': 'Cafes'},
#   {'address': '300 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-21',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 8,
#    'category': 'Parks'},
#   {'address': '1100 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-21',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 18,
#    'category': 'Cafes'},
#   {'address': '2000 E 3300 S, Salt Lake City, UT 84109',
#    'date': '2023-08-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': '376 E 400 S, Salt Lake City, UT 84111',
#    'date': '2023-08-22',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 14,
#    'category': 'Cafes'},
#   {'address': '1060 S 900 W, Salt Lake City, UT 84104',
#    'date': '2023-08-22',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 7,
#    'category': 'Parks'},
#   {'address': '200 S Central Campus Dr, Salt Lake City, UT 84112',
#    'date': '2023-08-22',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 22,
#    'category': 'Cafes'},
#   {'address': '300 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-23',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 5,
#    'category': 'Parks'},
#   {'address': '902 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-23',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 12,
#    'category': 'Cafes'},
#   {'address': '300 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-23',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 8,
#    'category': 'Parks'},
#   {'address': '1100 E 900 S, Salt Lake City, UT 84105',
#    'date': '2023-08-23',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 18,
#    'category': 'Cafes'},
#   {'address': '650 Wakara Way, Salt Lake City, UT 84108',
#    'date': '2023-08-24',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 5,
#    'category': 'Parks'},
#   {'address': '376 E 400 S, Salt Lake City, UT 84111',
#    'date': '2023-08-24',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 14,
#    'category': 'Cafes'},
#   {'address': '200 S Central Campus Dr, Salt Lake City, UT 84112',
#    'date': '2023-08-24',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 7,
#    'category': 'Parks'},
#   {'address': '1235 E Wilmington Ave, Salt Lake City, UT 84106',
#    'date': '2023-08-24',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Cafes'}],
#  [{'address': '123 Kloof Street, Cape Town, 8001',
#    'date': '2023-12-07',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafe'},
#   {'address': '37 Buitenkant Street, Cape Town, 8000',
#    'date': '2023-12-07',
#    'time_start': '11:00',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '15 Newlands Avenue, Newlands, Cape Town, 7700',
#    'date': '2023-12-07',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 30,
#    'category': 'Live Sports'},
#   {'address': '45 Long Street, Cape Town, 8000',
#    'date': '2023-12-08',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 7,
#    'category': 'Cafe'},
#   {'address': 'Dock Road, V&A Waterfront, Cape Town, 8001',
#    'date': '2023-12-08',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Shopping'},
#   {'address': 'V&A Waterfront, Cape Town, 8001',
#    'date': '2023-12-08',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 35,
#    'category': 'Live Sports'},
#   {'address': '78 Bree Street, Cape Town, 8001',
#    'date': '2023-12-09',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 6,
#    'category': 'Cafe'},
#   {'address': 'Victoria Wharf Shopping Centre, Cape Town, 8001',
#    'date': '2023-12-09',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 30,
#    'category': 'Shopping'},
#   {'address': 'Cape Town Stadium, Fritz Sonnenberg Rd, Green Point, Cape Town, 8051',
#    'date': '2023-12-09',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 40,
#    'category': 'Live Sports'},
#   {'address': '21 Loop Street, Cape Town, 8001',
#    'date': '2023-12-10',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 8,
#    'category': 'Cafe'},
#   {'address': 'Canal Walk Shopping Centre, Century Blvd, Century City, Cape Town, 7441',
#    'date': '2023-12-10',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 35,
#    'category': 'Shopping'},
#   {'address': 'Newlands Rugby Stadium, 8 Boundary Rd, Newlands, Cape Town, 7700',
#    'date': '2023-12-10',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': '98 Kloof Street, Cape Town, 8001',
#    'date': '2023-12-11',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 6,
#    'category': 'Cafe'},
#   {'address': 'Cavendish Square, Dreyer St, Claremont, Cape Town, 7708',
#    'date': '2023-12-11',
#    'time_start': '10:00',
#    'time_end': '13:00',
#    'price': 28,
#    'category': 'Shopping'},
#   {'address': 'Cape Town Stadium, Fritz Sonnenberg Rd, Green Point, Cape Town, 8051',
#    'date': '2023-12-11',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 40,
#    'category': 'Live Sports'}],
#  [{'address': '140 George St, The Rocks NSW 2000, Australia',
#    'date': '2023-08-17',
#    'time_start': '08:00',
#    'time_end': '09:00',
#    'price': 15,
#    'category': 'Cafe'},
#   {'address': 'Mrs Macquaries Rd, Sydney NSW 2000, Australia',
#    'date': '2023-08-17',
#    'time_start': '09:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Driver Ave, Moore Park NSW 2021, Australia',
#    'date': '2023-08-17',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1 Martin Pl, Sydney NSW 2000, Australia',
#    'date': '2023-08-17',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 20,
#    'category': 'Cafe'},
#   {'address': 'Bradleys Head Rd, Mosman NSW 2088, Australia',
#    'date': '2023-08-18',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Lang Rd, Moore Park NSW 2021, Australia',
#    'date': '2023-08-18',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': '10 Macquarie St, Sydney NSW 2000, Australia',
#    'date': '2023-08-18',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 18,
#    'category': 'Cafe'},
#   {'address': 'Darling Harbour, Sydney NSW 2000, Australia',
#    'date': '2023-08-19',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': '1 Olympic Blvd, Sydney Olympic Park NSW 2127, Australia',
#    'date': '2023-08-19',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 55,
#    'category': 'Live Sports'},
#   {'address': '500 George St, Sydney NSW 2000, Australia',
#    'date': '2023-08-19',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Cafe'},
#   {'address': 'Mrs Macquaries Rd, Sydney NSW 2000, Australia',
#    'date': '2023-08-20',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Driver Ave, Moore Park NSW 2021, Australia',
#    'date': '2023-08-20',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': '1 Martin Pl, Sydney NSW 2000, Australia',
#    'date': '2023-08-20',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 20,
#    'category': 'Cafe'},
#   {'address': 'Bradleys Head Rd, Mosman NSW 2088, Australia',
#    'date': '2023-08-21',
#    'time_start': '08:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Park'},
#   {'address': 'Lang Rd, Moore Park NSW 2021, Australia',
#    'date': '2023-08-21',
#    'time_start': '11:00',
#    'time_end': '14:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': '10 Macquarie St, Sydney NSW 2000, Australia',
#    'date': '2023-08-21',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 18,
#    'category': 'Cafe'}],
#  [{'address': 'Estr. da Canoa, 3300 - São Conrado, Rio de Janeiro - RJ, 22610-210, Brazil',
#    'date': '2023-10-05',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Atlântica, Copacabana, Rio de Janeiro - RJ, 22010-000, Brazil',
#    'date': '2023-10-05',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'R. Jardim Botânico, 1008 - Jardim Botânico, Rio de Janeiro - RJ, 22460-000, Brazil',
#    'date': '2023-10-05',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Borges de Medeiros, 997 - Lagoa, Rio de Janeiro - RJ, 22470-000, Brazil',
#    'date': '2023-10-06',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Maracanã, Rio de Janeiro - RJ, 20271-110, Brazil',
#    'date': '2023-10-06',
#    'time_start': '14:00',
#    'time_end': '17:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': 'R. Dias Ferreira, 679 - Leblon, Rio de Janeiro - RJ, 22431-050, Brazil',
#    'date': '2023-10-06',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 20,
#    'category': 'Cafes'},
#   {'address': 'Praça Mauá, 1 - Centro, Rio de Janeiro - RJ, 20081-240, Brazil',
#    'date': '2023-10-07',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 30,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Atlântica, Copacabana, Rio de Janeiro - RJ, 22010-000, Brazil',
#    'date': '2023-10-07',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'R. Marquês de São Vicente, 52 - Gávea, Rio de Janeiro - RJ, 22451-040, Brazil',
#    'date': '2023-10-07',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 45,
#    'category': 'Live Sports'},
#   {'address': 'Estr. do Pontal, 3295 - Recreio dos Bandeirantes, Rio de Janeiro - RJ, 22790-877, Brazil',
#    'date': '2023-10-08',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': 'R. Visconde de Caravelas, 113 - Botafogo, Rio de Janeiro - RJ, 22271-041, Brazil',
#    'date': '2023-10-08',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Av. Vieira Souto, 110 - Ipanema, Rio de Janeiro - RJ, 22420-000, Brazil',
#    'date': '2023-10-08',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': 'Av. Presidente Vargas, 2000 - Centro, Rio de Janeiro - RJ, 20210-030, Brazil',
#    'date': '2023-10-09',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 25,
#    'category': 'Sightseeing'},
#   {'address': 'R. do Lavradio, 132 - Centro, Rio de Janeiro - RJ, 20230-070, Brazil',
#    'date': '2023-10-09',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'Av. Maracanã, Rio de Janeiro - RJ, 20271-110, Brazil',
#    'date': '2023-10-09',
#    'time_start': '16:00',
#    'time_end': '19:00',
#    'price': 50,
#    'category': 'Live Sports'}],
#  {},
#  [{'address': 'Piazza del Duomo, 50122 Firenze FI, Italy',
#    'date': '2023-11-23',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 15,
#    'category': 'Art'},
#   {'address': 'Piazza della Signoria, 50122 Firenze FI, Italy',
#    'date': '2023-11-23',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 10,
#    'category': 'Museums'},
#   {'address': 'Viale Michelangiolo, 50125 Firenze FI, Italy',
#    'date': '2023-11-23',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': 'Via della Ninna, 5, 50122 Firenze FI, Italy',
#    'date': '2023-11-24',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 20,
#    'category': 'Museums'},
#   {'address': 'Piazzale degli Uffizi, 6, 50122 Firenze FI, Italy',
#    'date': '2023-11-24',
#    'time_start': '13:00',
#    'time_end': '16:00',
#    'price': 25,
#    'category': 'Art'},
#   {'address': 'Piazza di Santa Croce, 16, 50122 Firenze FI, Italy',
#    'date': '2023-11-24',
#    'time_start': '17:00',
#    'time_end': '19:00',
#    'price': 8,
#    'category': 'Museums'},
#   {'address': 'Piazza San Marco, 50121 Firenze FI, Italy',
#    'date': '2023-11-25',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 12,
#    'category': 'Art'},
#   {'address': 'Viale Galileo, 50125 Firenze FI, Italy',
#    'date': '2023-11-25',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': 'Via Ricasoli, 58/60, 50122 Firenze FI, Italy',
#    'date': '2023-11-25',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 16,
#    'category': 'Museums'},
#   {'address': 'Lungarno degli Acciaiuoli, 50123 Firenze FI, Italy',
#    'date': '2023-11-26',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': 'Piazza della Repubblica, 50123 Firenze FI, Italy',
#    'date': '2023-11-26',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 5,
#    'category': 'Museums'},
#   {'address': 'Piazza Pitti, 1, 50125 Firenze FI, Italy',
#    'date': '2023-11-26',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': 'Piazza San Lorenzo, 9, 50123 Firenze FI, Italy',
#    'date': '2023-11-27',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Museums'},
#   {'address': 'Piazza Santo Spirito, 50125 Firenze FI, Italy',
#    'date': '2023-11-27',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': 'Via Camillo Benso Cavour, 3, 50123 Firenze FI, Italy',
#    'date': '2023-11-27',
#    'time_start': '15:00',
#    'time_end': '18:00',
#    'price': 18,
#    'category': 'Museums'}],
#  [{'address': '105 Namsangongwon-gil, Yongsan-gu, Seoul',
#    'date': '2023-12-21',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': '14-5 Insadong-gil, Jongno-gu, Seoul',
#    'date': '2023-12-21',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '30 Samcheong-ro, Jongno-gu, Seoul',
#    'date': '2023-12-21',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 10,
#    'category': 'Art'},
#   {'address': '87 Yulgok-ro 3-gil, Jongno-gu, Seoul',
#    'date': '2023-12-21',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Shopping'},
#   {'address': '281 Eulji-ro, Jung-gu, Seoul',
#    'date': '2023-12-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': '19-3 Myeongdong 10-gil, Jung-gu, Seoul',
#    'date': '2023-12-22',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '54 Samseong-dong, Gangnam-gu, Seoul',
#    'date': '2023-12-22',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 25,
#    'category': 'Shopping'},
#   {'address': '513 Yeongdong-daero, Gangnam-gu, Seoul',
#    'date': '2023-12-22',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 20,
#    'category': 'Art'},
#   {'address': '28 Toegye-ro 34-gil, Jung-gu, Seoul',
#    'date': '2023-12-23',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': '1-1 Yulgok-ro, Jongno-gu, Seoul',
#    'date': '2023-12-23',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': '27 Dongdaemun-ro, Jongno-gu, Seoul',
#    'date': '2023-12-23',
#    'time_start': '13:30',
#    'time_end': '15:30',
#    'price': 30,
#    'category': 'Shopping'},
#   {'address': '50-1 Myeongdong 2(i)-ga, Jung-gu, Seoul',
#    'date': '2023-12-23',
#    'time_start': '16:00',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': '99 Sejong-daero, Jung-gu, Seoul',
#    'date': '2023-12-24',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Art'},
#   {'address': '23-1 Insadong-gil, Jongno-gu, Seoul',
#    'date': '2023-12-24',
#    'time_start': '11:30',
#    'time_end': '13:00',
#    'price': 20,
# ...
#    'date': '2023-10-23',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Calle de la Princesa, 3, 28008 Madrid, Spain',
#    'date': '2023-10-23',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bars'},
#   {'address': 'Avenida de Concha Espina, 1, 28036 Madrid, Spain',
#    'date': '2023-10-24',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Gran Vía, 12, 28013 Madrid, Spain',
#    'date': '2023-10-24',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 35,
#    'category': 'Bars'},
#   {'address': 'Calle Alcalá, 42, 28014 Madrid, Spain',
#    'date': '2023-10-25',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Calle de las Huertas, 12, 28012 Madrid, Spain',
#    'date': '2023-10-25',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 30,
#    'category': 'Bars'},
#   {'address': 'Calle de Velázquez, 34, 28001 Madrid, Spain',
#    'date': '2023-10-26',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Calle de la Montera, 10, 28013 Madrid, Spain',
#    'date': '2023-10-26',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 20,
#    'category': 'Bars'},
#   {'address': 'Calle de Alcalá, 13, 28014 Madrid, Spain',
#    'date': '2023-10-27',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Calle de la Reina, 5, 28004 Madrid, Spain',
#    'date': '2023-10-27',
#    'time_start': '20:00',
#    'time_end': '23:00',
#    'price': 25,
#    'category': 'Bars'}],
#  [{'address': 'Rua Augusta, 1100-048 Lisboa, Portugal',
#    'date': '2023-07-27',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Praça do Comércio, 1100-148 Lisboa, Portugal',
#    'date': '2023-07-27',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua Garrett, 1200-203 Lisboa, Portugal',
#    'date': '2023-07-27',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Restaurants'},
#   {'address': 'Avenida da Liberdade, 1250-096 Lisboa, Portugal',
#    'date': '2023-07-27',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua Nova do Carvalho, 1200-014 Lisboa, Portugal',
#    'date': '2023-07-27',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'Rua das Portas de Santo Antão, 1150-268 Lisboa, Portugal',
#    'date': '2023-07-27',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': 'Rua da Prata, 1100-420 Lisboa, Portugal',
#    'date': '2023-07-28',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Rua do Carmo, 1200-093 Lisboa, Portugal',
#    'date': '2023-07-28',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua Jardim do Regedor, 1150-193 Lisboa, Portugal',
#    'date': '2023-07-28',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': 'Rua do Ouro, 1150-060 Lisboa, Portugal',
#    'date': '2023-07-28',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua de São Bento, 1200-821 Lisboa, Portugal',
#    'date': '2023-07-28',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Rua do Salitre, 1250-198 Lisboa, Portugal',
#    'date': '2023-07-28',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': 'Rua das Flores, 1200-195 Lisboa, Portugal',
#    'date': '2023-07-29',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Rua do Alecrim, 1200-017 Lisboa, Portugal',
#    'date': '2023-07-29',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua de São Nicolau, 1100-547 Lisboa, Portugal',
#    'date': '2023-07-29',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Restaurants'},
#   {'address': 'Rua da Escola Politécnica, 1250-102 Lisboa, Portugal',
#    'date': '2023-07-29',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua do Século, 1200-434 Lisboa, Portugal',
#    'date': '2023-07-29',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'Rua do Telhal, 1150-345 Lisboa, Portugal',
#    'date': '2023-07-29',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': 'Rua da Madalena, 1100-319 Lisboa, Portugal',
#    'date': '2023-07-30',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Rua do Arsenal, 1100-038 Lisboa, Portugal',
#    'date': '2023-07-30',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua de São Mamede, 1100-533 Lisboa, Portugal',
#    'date': '2023-07-30',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': 'Rua do Crucifixo, 1100-182 Lisboa, Portugal',
#    'date': '2023-07-30',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua da Conceição, 1100-153 Lisboa, Portugal',
#    'date': '2023-07-30',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Rua do Benformoso, 1100-084 Lisboa, Portugal',
#    'date': '2023-07-30',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': 'Rua dos Fanqueiros, 1100-232 Lisboa, Portugal',
#    'date': '2023-07-31',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Rua da Palma, 1100-390 Lisboa, Portugal',
#    'date': '2023-07-31',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua do Milagre de Santo António, 1100-351 Lisboa, Portugal',
#    'date': '2023-07-31',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Restaurants'},
#   {'address': 'Rua da Prata, 1100-420 Lisboa, Portugal',
#    'date': '2023-07-31',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua de São Julião, 1100-524 Lisboa, Portugal',
#    'date': '2023-07-31',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'Rua da Vitória, 1100-618 Lisboa, Portugal',
#    'date': '2023-07-31',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 30,
#    'category': 'Restaurants'},
#   {'address': 'Rua dos Correeiros, 1100-162 Lisboa, Portugal',
#    'date': '2023-08-01',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Rua do Comércio, 1100-150 Lisboa, Portugal',
#    'date': '2023-08-01',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua de São Nicolau, 1100-547 Lisboa, Portugal',
#    'date': '2023-08-01',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 25,
#    'category': 'Restaurants'},
#   {'address': 'Rua da Madalena, 1100-319 Lisboa, Portugal',
#    'date': '2023-08-01',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua dos Bacalhoeiros, 1100-070 Lisboa, Portugal',
#    'date': '2023-08-01',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Rua da Conceição, 1100-153 Lisboa, Portugal',
#    'date': '2023-08-01',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 35,
#    'category': 'Restaurants'},
#   {'address': 'Rua dos Douradores, 1100-206 Lisboa, Portugal',
#    'date': '2023-08-02',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 5,
#    'category': 'Cafes'},
#   {'address': 'Rua do Crucifixo, 1100-182 Lisboa, Portugal',
#    'date': '2023-08-02',
#    'time_start': '10:30',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua da Vitória, 1100-618 Lisboa, Portugal',
#    'date': '2023-08-02',
#    'time_start': '12:30',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Restaurants'},
#   {'address': 'Rua dos Sapateiros, 1100-579 Lisboa, Portugal',
#    'date': '2023-08-02',
#    'time_start': '14:30',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Shopping'},
#   {'address': 'Rua dos Fanqueiros, 1100-232 Lisboa, Portugal',
#    'date': '2023-08-02',
#    'time_start': '16:30',
#    'time_end': '18:00',
#    'price': 15,
#    'category': 'Cafes'},
#   {'address': 'Rua dos Correeiros, 1100-162 Lisboa, Portugal',
#    'date': '2023-08-02',
#    'time_start': '19:00',
#    'time_end': '21:00',
#    'price': 30,
#    'category': 'Restaurants'}],
#  [{'address': 'Stadio Pier Luigi Penzo, Campo della Celestia, 30122 Venezia VE, Italy',
#    'date': '2023-08-21',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': 'Parco delle Rimembranze, 30132 Venezia VE, Italy',
#    'date': '2023-08-22',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Parco San Giuliano, Via Orlanda, 30173 Venezia VE, Italy',
#    'date': '2023-08-22',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Lido di Venezia, 30126 Venezia VE, Italy',
#    'date': '2023-08-23',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Stadio Pier Luigi Penzo, Campo della Celestia, 30122 Venezia VE, Italy',
#    'date': '2023-08-24',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 50,
#    'category': 'Live Sports'},
#   {'address': 'Parco delle Rimembranze, 30132 Venezia VE, Italy',
#    'date': '2023-08-25',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Parco San Giuliano, Via Orlanda, 30173 Venezia VE, Italy',
#    'date': '2023-08-25',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Lido di Venezia, 30126 Venezia VE, Italy',
#    'date': '2023-08-26',
#    'time_start': '10:00',
#    'time_end': '12:00',
#    'price': 0,
#    'category': 'Parks'},
#   {'address': 'Stadio Pier Luigi Penzo, Campo della Celestia, 30122 Venezia VE, Italy',
#    'date': '2023-08-27',
#    'time_start': '18:00',
#    'time_end': '20:00',
#    'price': 50,
#    'category': 'Live Sports'}],
#  [{'address': 'Golden Gate Bridge, San Francisco, CA 94129',
#    'date': '2023-07-02',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': "Fisherman's Wharf, San Francisco, CA 94133",
#    'date': '2023-07-02',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': 'Ocean Beach, San Francisco, CA 94121',
#    'date': '2023-07-02',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'Blue Bottle Coffee, 66 Mint St, San Francisco, CA 94103',
#    'date': '2023-07-02',
#    'time_start': '18:00',
#    'time_end': '19:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Alcatraz Island, San Francisco, CA 94133',
#    'date': '2023-07-03',
#    'time_start': '09:00',
#    'time_end': '12:00',
#    'price': 40,
#    'category': 'Sightseeing'},
#   {'address': 'Baker Beach, San Francisco, CA 94129',
#    'date': '2023-07-03',
#    'time_start': '13:00',
#    'time_end': '15:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'Sightglass Coffee, 270 7th St, San Francisco, CA 94103',
#    'date': '2023-07-03',
#    'time_start': '16:00',
#    'time_end': '17:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Lombard Street, San Francisco, CA 94133',
#    'date': '2023-07-04',
#    'time_start': '09:00',
#    'time_end': '10:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': 'Pier 39, San Francisco, CA 94133',
#    'date': '2023-07-04',
#    'time_start': '11:00',
#    'time_end': '13:00',
#    'price': 20,
#    'category': 'Sightseeing'},
#   {'address': 'Crissy Field Beach, San Francisco, CA 94129',
#    'date': '2023-07-04',
#    'time_start': '14:00',
#    'time_end': '16:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'Four Barrel Coffee, 375 Valencia St, San Francisco, CA 94103',
#    'date': '2023-07-04',
#    'time_start': '17:00',
#    'time_end': '18:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Twin Peaks, San Francisco, CA 94114',
#    'date': '2023-07-05',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': 'Sutro Baths, San Francisco, CA 94121',
#    'date': '2023-07-05',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': 'China Beach, San Francisco, CA 94121',
#    'date': '2023-07-05',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'Philz Coffee, 3101 24th St, San Francisco, CA 94110',
#    'date': '2023-07-05',
#    'time_start': '18:00',
#    'time_end': '19:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Coit Tower, 1 Telegraph Hill Blvd, San Francisco, CA 94133',
#    'date': '2023-07-06',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 10,
#    'category': 'Sightseeing'},
#   {'address': 'Palace of Fine Arts, 3601 Lyon St, San Francisco, CA 94123',
#    'date': '2023-07-06',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': "Marshall's Beach, San Francisco, CA 94129",
#    'date': '2023-07-06',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'Ritual Coffee Roasters, 1026 Valencia St, San Francisco, CA 94110',
#    'date': '2023-07-06',
#    'time_start': '18:00',
#    'time_end': '19:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'San Francisco Cable Car Museum, 1201 Mason St, San Francisco, CA 94108',
#    'date': '2023-07-07',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 8,
#    'category': 'Sightseeing'},
#   {'address': 'Ghirardelli Square, 900 North Point St, San Francisco, CA 94109',
#    'date': '2023-07-07',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 15,
#    'category': 'Sightseeing'},
#   {'address': 'Aquatic Park Cove, San Francisco, CA 94109',
#    'date': '2023-07-07',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'Cafe Réveille, 201 Steiner St, San Francisco, CA 94117',
#    'date': '2023-07-07',
#    'time_start': '18:00',
#    'time_end': '19:00',
#    'price': 10,
#    'category': 'Cafes'},
#   {'address': 'Painted Ladies, Steiner St & Hayes St, San Francisco, CA 94117',
#    'date': '2023-07-08',
#    'time_start': '09:00',
#    'time_end': '11:00',
#    'price': 0,
#    'category': 'Sightseeing'},
#   {'address': 'Exploratorium, Pier 15, The Embarcadero, San Francisco, CA 94111',
#    'date': '2023-07-08',
#    'time_start': '12:00',
#    'time_end': '14:00',
#    'price': 30,
#    'category': 'Sightseeing'},
#   {'address': 'Fort Funston, San Francisco, CA 94132',
#    'date': '2023-07-08',
#    'time_start': '15:00',
#    'time_end': '17:00',
#    'price': 0,
#    'category': 'Beaches'},
#   {'address': 'The Mill, 736 Divisadero St, San Francisco, CA 94117',
#    'date': '2023-07-08',
#    'time_start': '18:00',
#    'time_end': '19:00',
#    'price': 10,
#    'category': 'Cafes'}]]
